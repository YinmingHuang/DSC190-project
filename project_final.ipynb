# %%
pip install -q torch transformers langchain_chroma bitsandbytes langchain faiss-gpu langchain_huggingface langchain-community sentence-transformers  pacmap tqdm matplotlib datasets

# %%
pip install -q sentence_transformers

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
from tqdm.notebook import tqdm
import pandas as pd
import os
import csv
import sys
import numpy as np
import time
import random
from typing import Optional, List, Tuple
import matplotlib.pyplot as plt
import textwrap
import torch

import random
import torch
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertModel
from torch import nn
from torch.optim import Adam
from tqdm import tqdm
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Processing dataset

# %%
import json
from huggingface_hub import hf_hub_download

filepath = hf_hub_download(
    repo_id='McAuley-Lab/Amazon-C4',
    filename='sampled_item_metadata_1M.jsonl',
    repo_type='dataset'
)

item_pool = []
with open(filepath, 'r') as file:
    for line in file:
        item_pool.append(json.loads(line.strip()))

# %%
from datasets import load_dataset

dataset = load_dataset('McAuley-Lab/Amazon-C4')['test']

# %%
item_metadata_map = {item['item_id']: {'metadata': item['metadata'], 'category': item['category']} for item in item_pool}

# %%
# new_list = []
# for data in dataset:
#     item_id = data['item_id']
#     item_info = item_metadata_map.get(item_id, {'metadata': None, 'category': None})  # 找到 metadata 和 category
#     new_entry = {
#         'query': data['query'],
#         'item_id': item_id,
#         'metadata': item_info['metadata'],
#         'category': item_info['category']
#     }
#     new_list.append(new_entry)

# %%
new_list = []
for data in dataset:
    item_id = data['item_id']
    item_info = item_metadata_map.get(item_id, {'metadata': None, 'category': None})  # 找到 metadata 和 category

    # 检查 metadata 的长度
    metadata = item_info['metadata']
    if metadata is None or len(metadata.split()) < 10:  # 如果 metadata 为空或单词数少于 10
        continue  # 跳过该条数据

    # 构造新的条目
    new_entry = {
        'query': data['query'],
        'item_id': item_id,
        'metadata': metadata,
        'category': item_info['category']
    }
    new_list.append(new_entry)

# %%
print(len(new_list))
# Out:
# 20250

# %%
# 初始化两个列表，分别存储 query 和 passage
queries = []
passages = []

# 计算前 1/10 的数据长度
limit = max(1, len(new_list) // 20)  # 确保至少取 1 条

# 遍历 new_list
for idx, entry in enumerate(new_list):
    # 仅处理前 1/10 的 query
    if idx < limit:
        queries.append(f"query: {entry['query']}")
        # 所有 passage 都添加
        passages.append(f"passage: {entry['metadata']}")

# 合并所有 query 和 passage 到一个列表中，确保 query 在前，passage 在后
input_texts = queries + passages

# 打印结果
# print(input_texts)

# %%
# 从 item_pool 中随机打乱并划分训练集与测试集
RANDOM_SEED = 42
random.seed(RANDOM_SEED)

random.shuffle(new_list)  # 随机打乱
split_idx = int(0.9 * len(new_list))
train_pool = new_list[:split_idx]
test_pool = new_list[split_idx:]

# 提取 query 和 category，用于分类
def prepare_dataset(pool):
    queries = [item['metadata'] for item in pool if item['metadata'] and item['category']]
    categories = [item['category'] for item in pool if item['metadata'] and item['category']]
    return queries, categories

train_queries, train_categories = prepare_dataset(train_pool)
test_queries, test_categories = prepare_dataset(test_pool)

# 将 category 转换为索引
category_to_idx = {category: idx for idx, category in enumerate(set(train_categories))}
idx_to_category = {idx: category for category, idx in category_to_idx.items()}
train_labels = [category_to_idx[cat] for cat in train_categories]
test_labels = [category_to_idx[cat] for cat in test_categories]

# %%
class QueryDataset(Dataset):
    def __init__(self, queries, labels, tokenizer, max_len=128):
        self.queries = queries
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.queries)

    def __getitem__(self, idx):
        query = self.queries[idx]
        label = self.labels[idx]
        encoding = self.tokenizer(
            query,
            max_length=self.max_len,
            truncation=True,
            padding="max_length",
            return_tensors="pt",
        )
        return {
            "input_ids": encoding["input_ids"].squeeze(0),
            "attention_mask": encoding["attention_mask"].squeeze(0),
            "label": torch.tensor(label, dtype=torch.long),
        }

# 初始化 BERT tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# 创建 DataLoader
train_dataset = QueryDataset(train_queries, train_labels, tokenizer)
test_dataset = QueryDataset(test_queries, test_labels, tokenizer)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# 自动检测是否有可用的 GPU，如果没有，则使用 CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class QueryClassifier(nn.Module):
    def __init__(self, num_categories):
        super(QueryClassifier, self).__init__()
        self.bert = BertModel.from_pretrained("bert-base-uncased")
        self.classifier = nn.Sequential(
            nn.Linear(self.bert.config.hidden_size, 512),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(512, num_categories)
        )

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        cls_token = outputs.last_hidden_state[:, 0, :]  # [CLS] token embedding
        logits = self.classifier(cls_token)
        return logits

# 初始化模型
num_categories = len(category_to_idx)
model = QueryClassifier(num_categories).to(device)

# %%
def train_model(model, train_loader, test_loader, num_epochs=3, lr=1e-5):
    optimizer = Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    model.train()

    for epoch in range(num_epochs):
        total_loss = 0
        for batch in tqdm(train_loader, desc=f"Training Epoch {epoch+1}"):
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["label"].to(device)

            optimizer.zero_grad()
            outputs = model(input_ids, attention_mask)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}")

    return model

model = train_model(model, train_loader, test_loader, num_epochs=3)
# Out:
# Training Epoch 1: 100%|██████████| 570/570 [02:09<00:00,  4.42it/s]
# Epoch 1, Loss: 1.6271
# Training Epoch 2: 100%|██████████| 570/570 [02:08<00:00,  4.42it/s]
# Epoch 2, Loss: 0.6908
# Training Epoch 3: 100%|██████████| 570/570 [02:08<00:00,  4.43it/s]
# Epoch 3, Loss: 0.4623

# %%
def evaluate_model(model, test_loader, top_k=3):
    model.eval()
    all_labels = []
    all_predictions = []

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Evaluating"):
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["label"].to(device)

            outputs = model(input_ids, attention_mask)
            _, top_preds = torch.topk(outputs, k=top_k, dim=-1)

            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(top_preds.cpu().numpy())

    # 计算 Top-K 准确率
    top_k_accuracy = 0
    for label, preds in zip(all_labels, all_predictions):
        if label in preds:
            top_k_accuracy += 1

    top_k_accuracy /= len(all_labels)
    print(f"Top-{top_k} Accuracy: {top_k_accuracy:.4f}")

evaluate_model(model, test_loader, top_k=3)
# Out:
# Evaluating: 100%|██████████| 64/64 [00:08<00:00,  7.98it/s]
# Top-3 Accuracy: 0.9580

# %%
from torch.nn.functional import softmax

# 新建一个空列表存储结果
result_list = []

# 将模型设置为评估模式
model.eval()

# 遍历测试集
with torch.no_grad():
    for batch in test_loader:
        # print(batch)
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        # original_queries = batch["query"]  # 保存原始 query

        # 模型预测
        logits = model(input_ids, attention_mask)
        probabilities = softmax(logits, dim=-1)

        # 获取 top-3 类别
        top2_indices = torch.topk(probabilities, 2, dim=-1).indices.cpu().numpy()

        # 构造结果
        for top2 in top2_indices:
            # 获取 top-2 类别名称
            top2_categories = [idx_to_category[idx] for idx in top2]

            # 根据类别找到 `new_list` 中的 items
            matched_items = [
                {
                    "item_id": item["item_id"],
                    "metadata": item["metadata"],
                    "category": item["category"],
                }
                for item in new_list
                if item["category"] in top2_categories
            ]

            # 保存结果
            result_list.append({
                # "query": query,
                "top2_categories": top2_categories,
                "matched_items": matched_items
            })

# %%
for i, result in enumerate(result_list):
    result['query'] = test_pool[i]['query']
    result['real_category'] = test_pool[i]['category']
    result['real_item_id'] = test_pool[i]['item_id']

# 检查结果
print(result_list[0]['matched_items'])
# Out:
# [{'item_id': 'B0CBHH1FVK', 'metadata': 'Exercise Bike Stationary, CHAOKE Indoor Cycling Bike with Heavy Flywheel, Comfortable Seat Cushion, Silent Belt Drive and LCD Monitor for Home Gym Cardio Workout Training. .', 'category': 'Sports'}, {'item_id': 'B087PTNHMF', 'metadata': 'Air Intake Turbo Tube, Turbochagrer Intake Pipe Hose for Mercedes-Benz W172 SLK200 SLK250, W204 C180 C200 C250, W212 E200 E250 E250 M271 Engine, 2710901629 2710901729 2710902029 2711801819 2710901929. Air Intake Turbo Tube Intake Pipe Hose Replacement part number : 2710901629 2710901729 2710902029 2711801819 2710901929 Other part numbers : A2710901629 A2710901729 A2710902029 A2711801819 Fitment : for 2011-2016 Mercedes-Benz W172 SLK200 with M271 Engine for 2011-2016 Mercedes-Benz W172 SLK250 with M271 Engine for 2007-2013 Mercedes-Benz W204 C180 with M271 Engine for 2007-2013 Mercedes-Benz W204 C200 with M271 Engine for 2007-2013 Mercedes-Benz W204 C250 with M271 Engine for 2009-2016 Mercedes-Benz W212 E200 with M271 Engine for 2009-2016 Mercedes-Benz W212 E250 with M271 Engine for 2009-2016 Mercedes-Benz W212 E250 with M271 Engine Service : 2-yeras shelf life Any needed please message us We will response within 24 hours Package : 1x Air Intake Turbo Tube Intake Pipe Hose for Mercedes-Benz.', 'category': 'Automotive'}, {'item_id': 'B08PFD1WPY', 'metadata': 'CLIQ 4 Chair Bag Camping Chairs - Carry Bag Folding Chairs and Beach Chairs (1 Bag Only). .', 'category': 'Sports'}, {'item_id': 'B07TKDJ5Q7', 'metadata': 'Fenix PD36R Rechargeable Flashlight, 1600 Lumen USB-C Tactical Duty Light with Battery and LumenTac Organizer. .', 'category': 'Sports'}, {'item_id': 'B0BFVWD3ZD', 'metadata': '2Pcs Silicone Car Engine Heater Pad - 4 x 5 Self-Adhesive Oil Pan Heater Pad with 194°F Thermal Protector, 120V 150W Car Battery Warmer Pad Engine Block Heater Pad with 68 Long Power Cord (Orange). Cold temperatures can hinder vehicle lubrication and cause engine and transmission oil to thicken and circulate poorly. Use our Self-adhesive Oil Pan Heater Pad to give your vehicle a quick start in the cold winter, saving you valuable time. -----Features Engine Oil Heater reduces oil consistency, which better lubricates the engine and reduces its wear. Composed of wear-resistant silicone, waterproof, oil-proof and low-temperature resistant, built to last. Built-in automatic thermal protector, effectively prevents potential safety hazards caused by high temperature. Suitable for automotive parts with metal surfaces, such as engine oil pan, fuel tank, reservoir, transmission and more. -----Specification Material: Silicone Color: Orange Voltage: 120V Rated Power: 150W Size: 4L x 5W, 68 long power cord -----Package Included 2 x Silicone Engine Block Heater Pad -----Permanent Installation 1. Clean off any grease or dirt from the bottom of your oil pan and keep it dry. 2. Peel off the paper backing from the heater and stick the pad to the oil pan. 3. Plug the power cord into an outlet for instant warming. 【Pay Attention】 1. Always be careful when heating to prevent scalding burns. 2. Once applied, the heater pad will be permanently installed on the metal surface. 3. Recommended for automotive metal surfaces only, not for personal use or use on plastic.', 'category': 'Automotive'}, {'item_id': 'B084F9F2BL', 'metadata': 'SIR IUS LED - FT- 921 922 579 LED Canbus Reverse Backup Trunk Light Bulb for Car Truck Super Bright High Power 3030+4014 SMD White 6500K Pack of 2. .', 'category': 'Automotive'}, {'item_id': 'B0BCK8NP5S', 'metadata': "mignonnememe Ebike Front/Rear Wheel 20 1000W 48V Electric Bicycle Motor Conversion Motor Hub Black. Motor Specification: High Motor Efficiency: max 88.7% (Save Power) Torque: max torque 35 N.m. RPM: max 420 Speed: 0-40\xa0 km/h Support standard 6-hole type disc brake Front Integral Wheel Weight: 8.5\xa0 kg Available Wheel Tire Size: 20''x 2.125 Package: 1*wheel.", 'category': 'Sports'}, {'item_id': 'B075QNFGVT', 'metadata': 'OEM NEW Interior Driver Side Sun ...

# %%
# -*- coding: utf-8 -*-

import torch
import torch.nn.functional as F
from torch import Tensor
from transformers import AutoTokenizer, AutoModel
import gc

def average_pool(last_hidden_states: Tensor,
                 attention_mask: Tensor) -> Tensor:
    last_hidden = last_hidden_states.masked_fill(~attention_mask[..., None].bool(), 0.0)
    return last_hidden.sum(dim=1) / attention_mask.sum(dim=1)[..., None]


# 2. 初始化tokenizer和模型，并将模型移动到指定设备
tokenizer = AutoTokenizer.from_pretrained('intfloat/multilingual-e5-small')
model = AutoModel.from_pretrained('intfloat/multilingual-e5-small').to(device)

# %%
for result in result_list:
    query = []
    passages = []
    query.append(f"query: {result['query']}")
    for matched_item in result['matched_items']:
        passages.append(f"passage: {matched_item['metadata']}")
    # print(query)
    input_texts = query + passages
    batch_dict = tokenizer(
        input_texts,
        max_length=128,
        padding=True,
        truncation=True,
        return_tensors='pt'
    )

    batch_dict = {key: value.to(device) for key, value in batch_dict.items()}

    with torch.no_grad():
        outputs = model(**batch_dict)
        embeddings = average_pool(outputs.last_hidden_state, batch_dict['attention_mask'])

    embeddings = F.normalize(embeddings, p=2, dim=1)

    scores = (embeddings[:1] @ embeddings[1:].T) * 100
    print(scores)
    break
# Out:
# tensor([[80.7630, 78.2953, 76.5069,  ..., 77.1785, 80.3873, 80.8040]],
#        device='cuda:0')

# %%
import torch
import torch.nn.functional as F

for result in result_list:
    query = []
    passages = []
    query.append(f"query: {result['query']}")

    for matched_item in result['matched_items']:
        passages.append(f"passage: {matched_item['metadata']}")

    # Combine query and passages into input_texts
    input_texts = query + passages

    # Tokenize inputs
    batch_dict = tokenizer(
        input_texts,
        max_length=128,
        padding=True,
        truncation=True,
        return_tensors='pt'
    )
    batch_dict = {key: value.to(device) for key, value in batch_dict.items()}

    # Get embeddings
    with torch.no_grad():
        outputs = model(**batch_dict)
        embeddings = average_pool(outputs.last_hidden_state, batch_dict['attention_mask'])
    embeddings = F.normalize(embeddings, p=2, dim=1)

    # Compute scores
    scores = (embeddings[:1] @ embeddings[1:].T) * 100  # Compute similarity scores
    scores = scores.squeeze(0)  # Remove extra dimension for easier processing

    # Get top-10 scores and corresponding indices
    top_scores, top_indices = torch.topk(scores, k=1000)

    # Map top scores to matched_items and check their IDs
    top_matched_items = [result['matched_items'][idx] for idx in top_indices]
    print(result['real_item_id'])
    for i, matched_item in enumerate(top_matched_items):
        item_id = matched_item['item_id']
        is_real_item = item_id == result['real_item_id']
        print(f"Rank {i+1}: Score = {top_scores[i].item():.2f}, Item ID = {item_id}, Is Real Item: {is_real_item}")

    break  # Break after processing the first result (for debugging)
# Out:
# B0BP6WWSBD
# Rank 1: Score = 85.68, Item ID = B07JLTMQJT, Is Real Item: False
# Rank 2: Score = 85.63, Item ID = B0B6BD13Q9, Is Real Item: False
# Rank 3: Score = 85.32, Item ID = B0B464RB6B, Is Real Item: False
# Rank 4: Score = 85.14, Item ID = B0BFQ4YG6Z, Is Real Item: False
# Rank 5: Score = 85.07, Item ID = B0923LNLK7, Is Real Item: False
# Rank 6: Score = 84.90, Item ID = B09D2TRSHM, Is Real Item: False
# Rank 7: Score = 84.71, Item ID = B0BP6WWSBD, Is Real Item: True
# Rank 8: Score = 84.71, Item ID = B0BP6WWSBD, Is Real Item: True
# Rank 9: Score = 84.69, Item ID = B0C5H87577, Is Real Item: False
# Rank 10: Score = 84.65, Item ID = B09F35NTYT, Is Real Item: False
# Rank 11: Score = 84.65, Item ID = B09F35NTYT, Is Real Item: False
# Rank 12: Score = 84.61, Item ID = B08R2N5SDX, Is Real Item: False
# Rank 13: Score = 84.59, Item ID = B097RWW2PX, Is Real Item: False
# Rank 14: Score = 84.48, Item ID = B07D3PVBJ4, Is Real Item: False
# Rank 15: Score = 83.48, Item ID = B0B4689MYZ, Is Real Item: False
# Rank 16: Score = 83.48, Item ID = B0BZH7NHG4, Is Real Item: False
# Rank 17: Score = 83.43, Item ID = B09WV6GTB3, Is Real Item: False
# Rank 18: Score = 83.30, Item ID = B07C3TJ8MZ, Is Real Item: False
# Rank 19: Score = 83.24, Item ID = B085C2HMQP, Is Real Item: False
# Rank 20: Score = 83.12, Item ID = B07BFH9WZ7, Is Real Item: False
# Rank 21: Score = 83.06, Item ID = B0C8V52BLR, Is Real Item: False
# Rank 22: Score = 83.06, Item ID = B0B9MZZ96T, Is Real Item: False
# Rank 23: Score = 82.70, Item ID = B0BK8DQ4H1, Is Real Item: False
# Rank 24: Score = 82.53, Item ID = B09VMB3ZXF, Is Real Item: False
# Rank 25: Score = 82.51, Item ID = B07Y9WY7H7, Is Real Item: False
# Rank 26: Score = 82.44, Item ID = B0BD4L6DLK, Is Real Item: False
# Rank 27: Score = 82.40, Item ID = B0BMWP2FQT, Is Real Item: False
# Rank 28: Score = 82.37, Item ID = B0BTVP9DD3, Is Real Item: False
# Rank 29: Score = 82.25, Item ID = B09CPPX259, Is Real Item: False
# Rank 30: Score = 82.19, Item ID = B07PND3719, Is Real Item: False
# Rank 31: Score = 82.08, Item ID = B082QJ7H1R, Is Real Item: False
# Rank 32: Score = 82.05, Item ID = B09FSNP1X6, Is Real Item: False
# Rank 33: Score = 81.95, Item ID = B07CW55T4L, Is Real Item: False
# Rank 34: Score = 81.90, Item ID = B0C1BD44L9, Is Real Item: False
# Rank 35: Score = 81.89, Item ID = B0BYTJ6LDR, Is Real Item: False
# Rank 36: Score = 81.89, Item ID = B0012Q4IPY, Is Real Item: False
# Rank 37: Score = 81.88, Item ID = B0C6DMWBWR, Is Real Item: False
# Rank 38: Score = 81.86, Item ID = B07B8YJLGL, Is Real Item: False
# Rank 39: Score = 81.83, Item ID = B093WMF7NW, Is Real Item: False
# Rank 40: Score = 81.75, Item ID = B0B8F27R5H, Is Real Item: False
# Rank 41: Score = 81.74, Item ID = B0C7QDD8GQ, Is Real Item: False
# Rank 42: Score = 81.74, Item ID = B0BPD75QWJ, Is Real Item: False
# Rank 43: Score = 81.71, Item ID = B088183BKS, Is Real Item: False
# Rank 44: Score = 81.70, Item ID = B07RYPDSD8, Is Real Item: False
# Rank 45: Score = 81.70, Item ID = B07RYPDSD8, Is Real Item: False
# Rank 46: Score = 81.70, Item ID = B07RYPDSD8, Is Real Item: False
# Rank 47: Score = 81.69, Item ID = B0BZ1FQ7H7, Is Real Item: False
# Rank 48: Score = 81.66, Item ID = B093TQTHV7, Is Real Item: False
# Rank 49: Score = 81.60, Item ID = B0BCK8NP5S, Is Real Item: False
# Rank 50: Score = 81.59, Item ID = B0CBLQPNVT, Is Real Item: False
# Rank 51: Score = 81.59, Item ID = B08R3DSH37, Is Real Item: False
# Rank 52: Score = 81.56, Item ID = B0BBVGS829, Is Real Item: False
# Rank 53: Score = 81.55, Item ID = B09XWCTJMW, Is Real Item: False
# Rank 54: Score = 81.55, Item ID = B09XWCTJMW, Is Real Item: False
# Rank 55: Score = 81.54, Item ID = B08V56W7P2, Is Real Item: False
# Rank 56: Score = 81.53, Item ID = B08FCYPXDW, Is Real Item: False
# Rank 57: Score = 81.52, Item ID = B0BKRND182, Is Real Item: False
# Rank 58: Score = 81.45, Item ID = B07W46BX31, Is Real Item: False
# Rank 59: Score = 81.45, Item ID = B07W46BX31, Is Real Item: False
# Rank 60: Score = 81.45, Item ID = B08V6MJ2NR, Is Real Item: False
# Rank 61: Score = 81.44, Item ID = B0B56LGJRP, Is Real Item: False
# Rank 62: Score = 81.43, Item ID = B09D76KH3C, Is Real Item: False
# Rank 63: Score = 81.41, Item ID = B0C5T94ZYF, Is Real Item: False
# Rank 64: Score = 81.40, Item ID = B0BKR3ZXCS, Is Real Item: False
# Rank 65: Score = 81.40, Item ID = B0C2Z12XBN, Is Real Item: False
# Rank 66: Score = 81.40, Item ID = B00L3OYMTW, Is Real Item: False
# Rank 67: Score = 81.39, Item ID = B0C7438F3X, Is Real Item: False
# Rank 68: Score = 81.35, Item ID = B07GFTNRMN, Is Real Item: False
# Rank 69: Score = 81.34, Item ID = B0BR936C5F, Is Real Item: False
# Rank 70: Score = 81.34, Item ID = B0B1J74326, Is Real Item: False
# Rank 71: Score = 81.34, Item ID = B00074VON6, Is Real Item: False
# Rank 72: Score = 81.34, Item ID = B085WXKGHN, Is Real Item: False
# Rank 73: Score = 81.33, Item ID = B08MQVFTNS, Is Real Item: False
# Rank 74: Score = 81.32, Item ID = B089SJST2J, Is Real Item: False
# Rank 75: Score = 81.31, Item ID = B08NRW82B7, Is Real Item: False
# Rank 76: Score = 81.31, Item ID = B0BLWFN3L9, Is Real Item: False
# Rank 77: Score = 81.30, Item ID = B0C5J28NT9, Is Real Item: False
# Rank 78: Score = 81.27, Item ID = B00IITX6KQ, Is Real Item: False
# Rank 79: Score = 81.26, Item ID = B0BXHLWCR5, Is Real Item: False
# Rank 80: Score = 81.26, Item ID = B07GT3YLM8, Is Real Item: False
# Rank 81: Score = 81.24, Item ID = B000NZB60U, Is Real Item: False
# Rank 82: Score = 81.24, Item ID = B09DPBBZF6, Is Real Item: False
# Rank 83: Score = 81.24, Item ID = B09GPNY29D, Is Real Item: False
# Rank 84: Score = 81.21, Item ID = B0C3LQ7S9L, Is Real Item: False
# Rank 85: Score = 81.21, Item ID = B0BSVNHFRG, Is Real Item: False
# Rank 86: Score = 81.21, Item ID = B0BP64NLV1, Is Real Item: False
# Rank 87: Score = 81.20, Item ID = B0BQNBNS5K, Is Real Item: False
# Rank 88: Score = 81.18, Item ID = B0B1222NT8, Is Real Item: False
# Rank 89: Score = 81.18, Item ID = B092R36QFD, Is Real Item: False
# Rank 90: Score = 81.17, Item ID = B098NC7Q8T, Is Real Item: False
# Rank 91: Score = 81.17, Item ID = B0976R3WDB, Is Real Item: False
# Rank 92: Score = 81.17, Item ID = B0976R3WDB, Is Real Item: False
# Rank 93: Score = 81.15, Item ID = B092PVCQQP, Is Real Item: False
# Rank 94: Score = 81.14, Item ID = B0B3LLD5J4, Is Real Item: False
# Rank 95: Score = 81.13, Item ID = B01B3JZWDQ, Is Real Item: False
# Rank 96: Score = 81.11, Item ID = B08LTZQKYJ, Is Real Item: False
# Rank 97: Score = 81.10, Item ID = B08XN9YT2H, Is Real Item: False
# Rank 98: Score = 81.07, Item ID = B0C372DYSP, Is Real Item: False
# Rank 99: Score = 81.06, Item ID = B0922SKH8S, Is Real Item: False
# Rank 100: Score = 81.05, Item ID = B0B4NVC61B, Is Real Item: False
# Rank 101: Score = 81.02, Item ID = B07JGYWXFQ, Is Real Item: False
# Rank 102: Score = 81.01, Item ID = B08F37P7H3, Is Real Item: False
# Rank 103: Score = 81.00, Item ID = B01LWN4LSD, Is Real Item: False
# Rank 104: Score = 81.00, Item ID = B09YRQ3YKD, Is Real Item: False
# Rank 105: Score = 81.00, Item ID = B0BVR4VNGX, Is Real Item: False
# Rank 106: Score = 80.99, Item ID = B0B8MS1GDG, Is Real Item: False
# Rank 107: Score = 80.99, Item ID = B0BWDY68XZ, Is Real Item: False
# Rank 108: Score = 80.98, Item ID = B00Y1IQ5XS, Is Real Item: False
# Rank 109: Score = 80.97, Item ID = B0BDLKK1Z7, Is Real Item: False
# Rank 110: Score = 80.95, Item ID = B07ZCS4JD2, Is Real Item: False
# Rank 111: Score = 80.94, Item ID = B094D3M28L, Is Real Item: False
# Rank 112: Score = 80.92, Item ID = B0BXKS3DTZ, Is Real Item: False
# Rank 113: Score = 80.91, Item ID = B01MRUKFQ8, Is Real Item: False
# Rank 114: Score = 80.91, Item ID = B09PVFYJSP, Is Real Item: False
# Rank 115: Score = 80.90, Item ID = B0BZBVH9ZF, Is Real Item: False
# Rank 116: Score = 80.89, Item ID = B0C66WW1FK, Is Real Item: False
# Rank 117: Score = 80.88, Item ID = B0B4NS25CX, Is Real Item: False
# Rank 118: Score = 80.88, Item ID = B0BD7T34KZ, Is Real Item: False
# Rank 119: Score = 80.88, Item ID = B07PLNZQBQ, Is Real Item: False
# Rank 120: Score = 80.86, Item ID = B0C7QDXT6R, Is Real Item: False
# Rank 121: Score = 80.86, Item ID = B09DVPQQWW, Is Real Item: False
# Rank 122: Score = 80.86, Item ID = B0C621D9MS, Is Real Item: False
# Rank 123: Score = 80.86, Item ID = B0991V426W, Is Real Item: False
# Rank 124: Score = 80.85, Item ID = B0BHKMCJ24, Is Real Item: False
# Rank 125: Score = 80.83, Item ID = B0B1J7K4J9, Is Real Item: False
# Rank 126: Score = 80.82, Item ID = B00KDHJBAK, Is Real Item: False
# Rank 127: Score = 80.81, Item ID = B0855C9BGS, Is Real Item: False
# Rank 128: Score = 80.80, Item ID = B09SB9T4ZY, Is Real Item: False
# Rank 129: Score = 80.80, Item ID = B075WS4KX3, Is Real Item: False
# Rank 130: Score = 80.80, Item ID = B094DXJZPN, Is Real Item: False
# Rank 131: Score = 80.80, Item ID = B09W318F3C, Is Real Item: False
# Rank 132: Score = 80.79, Item ID = B00BYH6C1E, Is Real Item: False
# Rank 133: Score = 80.79, Item ID = B00BYH6C1E, Is Real Item: False
# Rank 134: Score = 80.78, Item ID = B09X5B29G4, Is Real Item: False
# Rank 135: Score = 80.78, Item ID = B0B7C11QK1, Is Real Item: False
# Rank 136: Score = 80.77, Item ID = B0BRSG7ZZW, Is Real Item: False
# Rank 137: Score = 80.77, Item ID = B09HGG2MC3, Is Real Item: False
# Rank 138: Score = 80.76, Item ID = B0CBHH1FVK, Is Real Item: False
# Rank 139: Score = 80.75, Item ID = B09PDTJ6B2, Is Real Item: False
# Rank 140: Score = 80.74, Item ID = B0BT3CQ2W9, Is Real Item: False
# Rank 141: Score = 80.74, Item ID = B08RMSJXHL, Is Real Item: False
# Rank 142: Score = 80.73, Item ID = B0BQ736V39, Is Real Item: False
# Rank 143: Score = 80.73, Item ID = B08M5Z19YD, Is Real Item: False
# Rank 144: Score = 80.73, Item ID = B07S2B8C46, Is Real Item: False
# Rank 145: Score = 80.72, Item ID = B0B5CBKC17, Is Real Item: False
# Rank 146: Score = 80.72, Item ID = B08Z5RY9VD, Is Real Item: False
# Rank 147: Score = 80.71, Item ID = B09N79S3WR, Is Real Item: False
# Rank 148: Score = 80.71, Item ID = B07RN9WKW2, Is Real Item: False
# Rank 149: Score = 80.71, Item ID = B099Y4DXWR, Is Real Item: False
# Rank 150: Score = 80.71, Item ID = B08SMM8XCJ, Is Real Item: False
# Rank 151: Score = 80.70, Item ID = B09TF1HBQ9, Is Real Item: False
# Rank 152: Score = 80.69, Item ID = B074HW532B, Is Real Item: False
# Rank 153: Score = 80.68, Item ID = B07PG6RXLN, Is Real Item: False
# Rank 154: Score = 80.68, Item ID = B09NXNLGNB, Is Real Item: False
# Rank 155: Score = 80.68, Item ID = B0BFQ6YND8, Is Real Item: False
# Rank 156: Score = 80.68, Item ID = B0BT5H9GQT, Is Real Item: False
# Rank 157: Score = 80.67, Item ID = B082MCSRC7, Is Real Item: False
# Rank 158: Score = 80.67, Item ID = B07F946Z1V, Is Real Item: False
# Rank 159: Score = 80.67, Item ID = B08BZ52P9G, Is Real Item: False
# Rank 160: Score = 80.67, Item ID = B07HRZMSZV, Is Real Item: False
# Rank 161: Score = 80.66, Item ID = B001GN3EVM, Is Real Item: False
# Rank 162: Score = 80.66, Item ID = B09474MX51, Is Real Item: False
# Rank 163: Score = 80.65, Item ID = B08YRCHX1V, Is Real Item: False
# Rank 164: Score = 80.65, Item ID = B0BSN6L2WY, Is Real Item: False
# Rank 165: Score = 80.64, Item ID = B091W7DQGB, Is Real Item: False
# Rank 166: Score = 80.64, Item ID = B09WVG38YF, Is Real Item: False
# Rank 167: Score = 80.63, Item ID = B0BTKC9XGJ, Is Real Item: False
# Rank 168: Score = 80.63, Item ID = B0BCF4JQB4, Is Real Item: False
# Rank 169: Score = 80.63, Item ID = B0949MX825, Is Real Item: False
# Rank 170: Score = 80.63, Item ID = B071F1KPPX, Is Real Item: False
# Rank 171: Score = 80.62, Item ID = B08M41FX48, Is Real Item: False
# Rank 172: Score = 80.62, Item ID = B08M41FX48, Is Real Item: False
# Rank 173: Score = 80.61, Item ID = B08NVS6PSK, Is Real Item: False
# Rank 174: Score = 80.61, Item ID = B00WW8CB14, Is Real Item: False
# Rank 175: Score = 80.60, Item ID = B09K7K9BCH, Is Real Item: False
# Rank 176: Score = 80.60, Item ID = B0BYN6LQ81, Is Real Item: False
# Rank 177: Score = 80.59, Item ID = B015D9VG14, Is Real Item: False
# Rank 178: Score = 80.58, Item ID = B0B1DF4RS8, Is Real Item: False
# Rank 179: Score = 80.58, Item ID = B09FCDYBQM, Is Real Item: False
# Rank 180: Score = 80.57, Item ID = B07ZMK6NFH, Is Real Item: False
# Rank 181: Score = 80.57, Item ID = B0BRPQW13G, Is Real Item: False
# Rank 182: Score = 80.57, Item ID = B07ZYLHVSM, Is Real Item: False
# Rank 183: Score = 80.57, Item ID = B07P7ZXG88, Is Real Item: False
# Rank 184: Score = 80.54, Item ID = B0C4T6RPWP, Is Real Item: False
# Rank 185: Score = 80.53, Item ID = B09WDKSHTN, Is Real Item: False
# Rank 186: Score = 80.52, Item ID = B0BXY5YPTF, Is Real Item: False
# Rank 187: Score = 80.52, Item ID = B0BN48GMPC, Is Real Item: False
# Rank 188: Score = 80.52, Item ID = B093S2RT5L, Is Real Item: False
# Rank 189: Score = 80.51, Item ID = B09C2P6149, Is Real Item: False
# Rank 190: Score = 80.50, Item ID = B07MQLDJLW, Is Real Item: False
# Rank 191: Score = 80.48, Item ID = B0BB1NYJGH, Is Real Item: False
# Rank 192: Score = 80.48, Item ID = B09DRN3R5Y, Is Real Item: False
# Rank 193: Score = 80.48, Item ID = B0BSSHSP5T, Is Real Item: False
# Rank 194: Score = 80.47, Item ID = B0B7DBF4FD, Is Real Item: False
# Rank 195: Score = 80.45, Item ID = B08QRNRGFH, Is Real Item: False
# Rank 196: Score = 80.45, Item ID = B0C6R8QGWR, Is Real Item: False
# Rank 197: Score = 80.45, Item ID = B09QG4V28S, Is Real Item: False
# Rank 198: Score = 80.45, Item ID = B079563N8K, Is Real Item: False
# Rank 199: Score = 80.44, Item ID = B09BKHDKNV, Is Real Item: False
# Rank 200: Score = 80.43, Item ID = B07J6PB432, Is Real Item: False
# Rank 201: Score = 80.43, Item ID = B08BZ67DX5, Is Real Item: False
# Rank 202: Score = 80.41, Item ID = B09S7J63RD, Is Real Item: False
# Rank 203: Score = 80.41, Item ID = B08Y93M3N3, Is Real Item: False
# Rank 204: Score = 80.40, Item ID = B0B2P7CMT7, Is Real Item: False
# Rank 205: Score = 80.39, Item ID = B09V5B58QV, Is Real Item: False
# Rank 206: Score = 80.39, Item ID = B0C22RJ6FM, Is Real Item: False
# Rank 207: Score = 80.39, Item ID = B0BBQNYLNP, Is Real Item: False
# Rank 208: Score = 80.39, Item ID = B0BNXGRCKM, Is Real Item: False
# Rank 209: Score = 80.39, Item ID = B08NNBYRH7, Is Real Item: False
# Rank 210: Score = 80.39, Item ID = B08P5X5DLX, Is Real Item: False
# Rank 211: Score = 80.39, Item ID = B00MPGSLLW, Is Real Item: False
# Rank 212: Score = 80.38, Item ID = B0BZCRTH2H, Is Real Item: False
# Rank 213: Score = 80.38, Item ID = B09TRD4MNG, Is Real Item: False
# Rank 214: Score = 80.37, Item ID = B07MRZWVVG, Is Real Item: False
# Rank 215: Score = 80.37, Item ID = B07SW1RHRP, Is Real Item: False
# Rank 216: Score = 80.37, Item ID = B0BNNRWZJ2, Is Real Item: False
# Rank 217: Score = 80.37, Item ID = B0B1M7NPXT, Is Real Item: False
# Rank 218: Score = 80.36, Item ID = B09Z2P7GKR, Is Real Item: False
# Rank 219: Score = 80.36, Item ID = B0BLW9QDVM, Is Real Item: False
# Rank 220: Score = 80.35, Item ID = B076J5HCWP, Is Real Item: False
# Rank 221: Score = 80.35, Item ID = B09HS97PPM, Is Real Item: False
# Rank 222: Score = 80.35, Item ID = B095YM1RG2, Is Real Item: False
# Rank 223: Score = 80.35, Item ID = B09ZVKVXDT, Is Real Item: False
# Rank 224: Score = 80.33, Item ID = B09W2QFXHD, Is Real Item: False
# Rank 225: Score = 80.33, Item ID = B08RS1NKDW, Is Real Item: False
# Rank 226: Score = 80.32, Item ID = B08CFV58K2, Is Real Item: False
# Rank 227: Score = 80.32, Item ID = B07GCYKH1C, Is Real Item: False
# Rank 228: Score = 80.32, Item ID = B0C7RCZD9Q, Is Real Item: False
# Rank 229: Score = 80.32, Item ID = B0049CK5PK, Is Real Item: False
# Rank 230: Score = 80.31, Item ID = B0CDRS3H9Y, Is Real Item: False
# Rank 231: Score = 80.30, Item ID = B0028QGTVS, Is Real Item: False
# Rank 232: Score = 80.30, Item ID = B0BH2WGL6M, Is Real Item: False
# Rank 233: Score = 80.29, Item ID = B000TQ16HG, Is Real Item: False
# Rank 234: Score = 80.29, Item ID = B007EA6WQU, Is Real Item: False
# Rank 235: Score = 80.29, Item ID = B002MUW202, Is Real Item: False
# Rank 236: Score = 80.29, Item ID = B07Z67MMGC, Is Real Item: False
# Rank 237: Score = 80.29, Item ID = B07D669GL2, Is Real Item: False
# Rank 238: Score = 80.27, Item ID = B085VG8XMG, Is Real Item: False
# Rank 239: Score = 80.27, Item ID = B09X5Q4MVD, Is Real Item: False
# Rank 240: Score = 80.26, Item ID = B0C23NDXD8, Is Real Item: False
# Rank 241: Score = 80.26, Item ID = B08KDZ3NVF, Is Real Item: False
# Rank 242: Score = 80.26, Item ID = B08JHMBZWY, Is Real Item: False
# Rank 243: Score = 80.25, Item ID = B0831KS3YW, Is Real Item: False
# Rank 244: Score = 80.23, Item ID = B0B1DJZQVL, Is Real Item: False
# Rank 245: Score = 80.22, Item ID = B09JFX785L, Is Real Item: False
# Rank 246: Score = 80.22, Item ID = B0C1CGCDK1, Is Real Item: False
# Rank 247: Score = 80.22, Item ID = B0B293JC9Z, Is Real Item: False
# Rank 248: Score = 80.22, Item ID = B0B4W419V4, Is Real Item: False
# Rank 249: Score = 80.21, Item ID = B09DYBC1DQ, Is Real Item: False
# Rank 250: Score = 80.21, Item ID = B0026JK8C8, Is Real Item: False
# Rank 251: Score = 80.20, Item ID = B09MZ84G7T, Is Real Item: False
# Rank 252: Score = 80.20, Item ID = B09Z2623DX, Is Real Item: False
# Rank 253: Score = 80.19, Item ID = B09K7Y6LCL, Is Real Item: False
# Rank 254: Score = 80.19, Item ID = B000EQW1AC, Is Real Item: False
# Rank 255: Score = 80.19, Item ID = B0872255PS, Is Real Item: False
# Rank 256: Score = 80.19, Item ID = B0B4PJFFM1, Is Real Item: False
# Rank 257: Score = 80.19, Item ID = B0BXT8HXPD, Is Real Item: False
# Rank 258: Score = 80.18, Item ID = B07NXPG9MZ, Is Real Item: False
# Rank 259: Score = 80.17, Item ID = B0919H77FL, Is Real Item: False
# Rank 260: Score = 80.17, Item ID = B00F3D3UDS, Is Real Item: False
# Rank 261: Score = 80.16, Item ID = B0B3VYY249, Is Real Item: False
# Rank 262: Score = 80.15, Item ID = B0BS5TP2X3, Is Real Item: False
# Rank 263: Score = 80.14, Item ID = B08ZCSWD2J, Is Real Item: False
# Rank 264: Score = 80.14, Item ID = B0C6ZFGM7D, Is Real Item: False
# Rank 265: Score = 80.13, Item ID = B09NZTN9D2, Is Real Item: False
# Rank 266: Score = 80.13, Item ID = B0967QT47K, Is Real Item: False
# Rank 267: Score = 80.13, Item ID = B0B5X417FH, Is Real Item: False
# Rank 268: Score = 80.13, Item ID = B004WO9TEI, Is Real Item: False
# Rank 269: Score = 80.11, Item ID = B0C9QTL1LV, Is Real Item: False
# Rank 270: Score = 80.10, Item ID = B0BBH97FNL, Is Real Item: False
# Rank 271: Score = 80.10, Item ID = B08RZ24ZC4, Is Real Item: False
# Rank 272: Score = 80.10, Item ID = B09W8G4XCJ, Is Real Item: False
# Rank 273: Score = 80.10, Item ID = B06XRZW1LD, Is Real Item: False
# Rank 274: Score = 80.10, Item ID = B0C54BTFGQ, Is Real Item: False
# Rank 275: Score = 80.10, Item ID = B0BN833CNL, Is Real Item: False
# Rank 276: Score = 80.09, Item ID = B09ZPDB43F, Is Real Item: False
# Rank 277: Score = 80.09, Item ID = B0BJQTSL4T, Is Real Item: False
# Rank 278: Score = 80.09, Item ID = B07PDHB7RL, Is Real Item: False
# Rank 279: Score = 80.08, Item ID = B07RQW6SD5, Is Real Item: False
# Rank 280: Score = 80.08, Item ID = B0BNK7HHLB, Is Real Item: False
# Rank 281: Score = 80.06, Item ID = B08Q7JV7CH, Is Real Item: False
# Rank 282: Score = 80.06, Item ID = B07XLP3WZK, Is Real Item: False
# Rank 283: Score = 80.06, Item ID = B07XLP3WZK, Is Real Item: False
# Rank 284: Score = 80.06, Item ID = B08CXDZMNK, Is Real Item: False
# Rank 285: Score = 80.05, Item ID = B08DHT3JNT, Is Real Item: False
# Rank 286: Score = 80.05, Item ID = B0B8MG2M6M, Is Real Item: False
# Rank 287: Score = 80.05, Item ID = B09PR3QHX9, Is Real Item: False
# Rank 288: Score = 80.05, Item ID = B0BL3CWVB6, Is Real Item: False
# Rank 289: Score = 80.05, Item ID = B0BJ616R58, Is Real Item: False
# Rank 290: Score = 80.05, Item ID = B0913FKVVH, Is Real Item: False
# Rank 291: Score = 80.05, Item ID = B0CB91P3XY, Is Real Item: False
# Rank 292: Score = 80.05, Item ID = B0BX61NXKP, Is Real Item: False
# Rank 293: Score = 80.04, Item ID = B0B4SJXP9W, Is Real Item: False
# Rank 294: Score = 80.04, Item ID = B09YXV3CRR, Is Real Item: False
# Rank 295: Score = 80.03, Item ID = B09BG43VQ8, Is Real Item: False
# Rank 296: Score = 80.03, Item ID = B00KQV1B5Q, Is Real Item: False
# Rank 297: Score = 80.03, Item ID = B07SYV9PDK, Is Real Item: False
# Rank 298: Score = 80.02, Item ID = B003AVZEZW, Is Real Item: False
# Rank 299: Score = 80.00, Item ID = B08JMG94X4, Is Real Item: False
# Rank 300: Score = 80.00, Item ID = B0C58YDQ5H, Is Real Item: False
# Rank 301: Score = 79.99, Item ID = B09Q8P1WPQ, Is Real Item: False
# Rank 302: Score = 79.99, Item ID = B09PYBGVSQ, Is Real Item: False
# Rank 303: Score = 79.99, Item ID = B0951TFZNP, Is Real Item: False
# Rank 304: Score = 79.98, Item ID = B0BVG7XQCF, Is Real Item: False
# Rank 305: Score = 79.98, Item ID = B0BHVCF9ND, Is Real Item: False
# Rank 306: Score = 79.98, Item ID = B0BQJ19HLQ, Is Real Item: False
# Rank 307: Score = 79.97, Item ID = B0B7KJ33HD, Is Real Item: False
# Rank 308: Score = 79.97, Item ID = B0C513WC2S, Is Real Item: False
# Rank 309: Score = 79.97, Item ID = B08KLGHHFK, Is Real Item: False
# Rank 310: Score = 79.96, Item ID = B007C68PNY, Is Real Item: False
# Rank 311: Score = 79.96, Item ID = B0B7KVMRZV, Is Real Item: False
# Rank 312: Score = 79.96, Item ID = B000FZZRS0, Is Real Item: False
# Rank 313: Score = 79.96, Item ID = B093GTJQ6D, Is Real Item: False
# Rank 314: Score = 79.96, Item ID = B0C6LY1ZVF, Is Real Item: False
# Rank 315: Score = 79.96, Item ID = B0BG7ZDJGK, Is Real Item: False
# Rank 316: Score = 79.95, Item ID = B002Y35O5W, Is Real Item: False
# Rank 317: Score = 79.94, Item ID = B09X51829R, Is Real Item: False
# Rank 318: Score = 79.93, Item ID = B09TT5C87K, Is Real Item: False
# Rank 319: Score = 79.93, Item ID = B07YDB31G4, Is Real Item: False
# Rank 320: Score = 79.93, Item ID = B0C5XDB8HJ, Is Real Item: False
# Rank 321: Score = 79.93, Item ID = B0C5XDB8HJ, Is Real Item: False
# Rank 322: Score = 79.92, Item ID = B000GVD0VE, Is Real Item: False
# Rank 323: Score = 79.92, Item ID = B0B5FLNCFJ, Is Real Item: False
# Rank 324: Score = 79.91, Item ID = B0BB45HTJ6, Is Real Item: False
# Rank 325: Score = 79.91, Item ID = B09RSZ1682, Is Real Item: False
# Rank 326: Score = 79.89, Item ID = B001Q891SW, Is Real Item: False
# Rank 327: Score = 79.89, Item ID = B0BC8M3Q8V, Is Real Item: False
# Rank 328: Score = 79.89, Item ID = B0B2KJWNQ1, Is Real Item: False
# Rank 329: Score = 79.89, Item ID = B07XM63SBR, Is Real Item: False
# Rank 330: Score = 79.89, Item ID = B0BK4K4W9N, Is Real Item: False
# Rank 331: Score = 79.89, Item ID = B09D5PC4HZ, Is Real Item: False
# Rank 332: Score = 79.88, Item ID = B00NF0KIP4, Is Real Item: False
# Rank 333: Score = 79.88, Item ID = B0B14XW4WN, Is Real Item: False
# Rank 334: Score = 79.88, Item ID = B00652G4TS, Is Real Item: False
# Rank 335: Score = 79.88, Item ID = B07FBTDV6Q, Is Real Item: False
# Rank 336: Score = 79.88, Item ID = B09GXNWPN7, Is Real Item: False
# Rank 337: Score = 79.87, Item ID = B09BYKJ2HC, Is Real Item: False
# Rank 338: Score = 79.87, Item ID = B09JC57GKM, Is Real Item: False
# Rank 339: Score = 79.87, Item ID = B09GLDZYQB, Is Real Item: False
# Rank 340: Score = 79.87, Item ID = B09TB4GPRJ, Is Real Item: False
# Rank 341: Score = 79.87, Item ID = B098PYB8XG, Is Real Item: False
# Rank 342: Score = 79.86, Item ID = B09Q38XR31, Is Real Item: False
# Rank 343: Score = 79.86, Item ID = B076P1C4GC, Is Real Item: False
# Rank 344: Score = 79.86, Item ID = B09Q66XKR1, Is Real Item: False
# Rank 345: Score = 79.86, Item ID = B09TK4JTQM, Is Real Item: False
# Rank 346: Score = 79.85, Item ID = B0BVJT272J, Is Real Item: False
# Rank 347: Score = 79.85, Item ID = B098N7QMGC, Is Real Item: False
# Rank 348: Score = 79.85, Item ID = B00KVZAOFA, Is Real Item: False
# Rank 349: Score = 79.84, Item ID = B09CJH4WPR, Is Real Item: False
# Rank 350: Score = 79.84, Item ID = B001QT9KO6, Is Real Item: False
# Rank 351: Score = 79.84, Item ID = B09L9W4HJB, Is Real Item: False
# Rank 352: Score = 79.83, Item ID = B0BXKSHXVY, Is Real Item: False
# Rank 353: Score = 79.83, Item ID = B0B5VNB33P, Is Real Item: False
# Rank 354: Score = 79.83, Item ID = B0B8QBTS8D, Is Real Item: False
# Rank 355: Score = 79.83, Item ID = B0BR367T9L, Is Real Item: False
# Rank 356: Score = 79.82, Item ID = B0C1FPFTG2, Is Real Item: False
# Rank 357: Score = 79.82, Item ID = B0B3STBY2J, Is Real Item: False
# Rank 358: Score = 79.81, Item ID = B07PMCPH7K, Is Real Item: False
# Rank 359: Score = 79.80, Item ID = B07DG4RYFM, Is Real Item: False
# Rank 360: Score = 79.80, Item ID = B0BTD9Y5HT, Is Real Item: False
# Rank 361: Score = 79.80, Item ID = B0C7XNZM5T, Is Real Item: False
# Rank 362: Score = 79.80, Item ID = B0BKL1GSZL, Is Real Item: False
# Rank 363: Score = 79.79, Item ID = B0BT61B73Q, Is Real Item: False
# Rank 364: Score = 79.79, Item ID = B0B93P9BNY, Is Real Item: False
# Rank 365: Score = 79.79, Item ID = B07GRC7BYY, Is Real Item: False
# Rank 366: Score = 79.78, Item ID = B099J97DMD, Is Real Item: False
# Rank 367: Score = 79.78, Item ID = B00XH886ZS, Is Real Item: False
# Rank 368: Score = 79.77, Item ID = B0BFBQZZMC, Is Real Item: False
# Rank 369: Score = 79.77, Item ID = B0BRWV1253, Is Real Item: False
# Rank 370: Score = 79.76, Item ID = B0BD53MQ1S, Is Real Item: False
# Rank 371: Score = 79.74, Item ID = B0BVVB4SX4, Is Real Item: False
# Rank 372: Score = 79.74, Item ID = B07NWDKX2N, Is Real Item: False
# Rank 373: Score = 79.74, Item ID = B0BBMZ9528, Is Real Item: False
# Rank 374: Score = 79.74, Item ID = B094VQ88X2, Is Real Item: False
# Rank 375: Score = 79.73, Item ID = B0BHY59CS7, Is Real Item: False
# Rank 376: Score = 79.72, Item ID = B09ZVDCLZK, Is Real Item: False
# Rank 377: Score = 79.71, Item ID = B00BJMF832, Is Real Item: False
# Rank 378: Score = 79.71, Item ID = B07H9YMLF9, Is Real Item: False
# Rank 379: Score = 79.71, Item ID = B0B4HY1RGV, Is Real Item: False
# Rank 380: Score = 79.71, Item ID = B07WMY298S, Is Real Item: False
# Rank 381: Score = 79.71, Item ID = B08L7TTSY9, Is Real Item: False
# Rank 382: Score = 79.70, Item ID = B08ZSPHHNW, Is Real Item: False
# Rank 383: Score = 79.70, Item ID = B09LXXXHRQ, Is Real Item: False
# Rank 384: Score = 79.70, Item ID = B0862HSJSG, Is Real Item: False
# Rank 385: Score = 79.70, Item ID = B0C4Z7KMKM, Is Real Item: False
# Rank 386: Score = 79.70, Item ID = B091P9QXX7, Is Real Item: False
# Rank 387: Score = 79.70, Item ID = B0C6GRYG6S, Is Real Item: False
# Rank 388: Score = 79.70, Item ID = B0BBMB4CDC, Is Real Item: False
# Rank 389: Score = 79.69, Item ID = B0BD481G3B, Is Real Item: False
# Rank 390: Score = 79.69, Item ID = B0BFQRC815, Is Real Item: False
# Rank 391: Score = 79.69, Item ID = B0C5X79RKL, Is Real Item: False
# Rank 392: Score = 79.69, Item ID = B07RS51G64, Is Real Item: False
# Rank 393: Score = 79.68, Item ID = B08H4C234W, Is Real Item: False
# Rank 394: Score = 79.68, Item ID = B09P4T34SQ, Is Real Item: False
# Rank 395: Score = 79.68, Item ID = B07B8PP7GP, Is Real Item: False
# Rank 396: Score = 79.68, Item ID = B09ST6PM38, Is Real Item: False
# Rank 397: Score = 79.68, Item ID = B09KH9G3N8, Is Real Item: False
# Rank 398: Score = 79.68, Item ID = B07HZQLZ5T, Is Real Item: False
# Rank 399: Score = 79.67, Item ID = B0BJQ3HWLW, Is Real Item: False
# Rank 400: Score = 79.67, Item ID = B07F35ZS7S, Is Real Item: False
# Rank 401: Score = 79.67, Item ID = B07CL8D6V5, Is Real Item: False
# Rank 402: Score = 79.67, Item ID = B0BT1KWZKH, Is Real Item: False
# Rank 403: Score = 79.66, Item ID = B07DNK83WF, Is Real Item: False
# Rank 404: Score = 79.65, Item ID = B07WGCG4CM, Is Real Item: False
# Rank 405: Score = 79.64, Item ID = B09KRL8FML, Is Real Item: False
# Rank 406: Score = 79.64, Item ID = B09LVF3LNX, Is Real Item: False
# Rank 407: Score = 79.63, Item ID = B0BNM79G35, Is Real Item: False
# Rank 408: Score = 79.63, Item ID = B08CNN2RLT, Is Real Item: False
# Rank 409: Score = 79.62, Item ID = B097M4LLJN, Is Real Item: False
# Rank 410: Score = 79.62, Item ID = B0C69K84M4, Is Real Item: False
# Rank 411: Score = 79.61, Item ID = B09Z47C9MD, Is Real Item: False
# Rank 412: Score = 79.61, Item ID = B08CB1XYM1, Is Real Item: False
# Rank 413: Score = 79.61, Item ID = B01GU88SV8, Is Real Item: False
# Rank 414: Score = 79.60, Item ID = B0C38RQM9Y, Is Real Item: False
# Rank 415: Score = 79.60, Item ID = B0827BS754, Is Real Item: False
# Rank 416: Score = 79.59, Item ID = B088WH6HBM, Is Real Item: False
# Rank 417: Score = 79.59, Item ID = B09R9PGRF4, Is Real Item: False
# Rank 418: Score = 79.59, Item ID = B0B3XS96SB, Is Real Item: False
# Rank 419: Score = 79.59, Item ID = B09ZK74QVQ, Is Real Item: False
# Rank 420: Score = 79.59, Item ID = B093DV9YGQ, Is Real Item: False
# Rank 421: Score = 79.58, Item ID = B09XXJ43KF, Is Real Item: False
# Rank 422: Score = 79.57, Item ID = B000IXRMSM, Is Real Item: False
# Rank 423: Score = 79.57, Item ID = B09NBN6Y64, Is Real Item: False
# Rank 424: Score = 79.56, Item ID = B00OPOU6J2, Is Real Item: False
# Rank 425: Score = 79.56, Item ID = B08B8ZL1KN, Is Real Item: False
# Rank 426: Score = 79.56, Item ID = B09MM6Q7H2, Is Real Item: False
# Rank 427: Score = 79.55, Item ID = B0B2VS1YHC, Is Real Item: False
# Rank 428: Score = 79.54, Item ID = B07D9BY5M2, Is Real Item: False
# Rank 429: Score = 79.54, Item ID = B08SQN5R5L, Is Real Item: False
# Rank 430: Score = 79.54, Item ID = B09FYHPWZ4, Is Real Item: False
# Rank 431: Score = 79.54, Item ID = B0969P7WRM, Is Real Item: False
# Rank 432: Score = 79.53, Item ID = B09XDP44CM, Is Real Item: False
# Rank 433: Score = 79.53, Item ID = B09XB46PFQ, Is Real Item: False
# Rank 434: Score = 79.52, Item ID = B0B829WR28, Is Real Item: False
# Rank 435: Score = 79.52, Item ID = B0BJCYZ2N3, Is Real Item: False
# Rank 436: Score = 79.51, Item ID = B0B43376GB, Is Real Item: False
# Rank 437: Score = 79.50, Item ID = B098KTMYTG, Is Real Item: False
# Rank 438: Score = 79.50, Item ID = B0B5QBS1DB, Is Real Item: False
# Rank 439: Score = 79.50, Item ID = B06XTP3HDG, Is Real Item: False
# Rank 440: Score = 79.50, Item ID = B09YH82R27, Is Real Item: False
# Rank 441: Score = 79.50, Item ID = B0BNM389HC, Is Real Item: False
# Rank 442: Score = 79.49, Item ID = B0C443HRYY, Is Real Item: False
# Rank 443: Score = 79.49, Item ID = B09784ZP2R, Is Real Item: False
# Rank 444: Score = 79.49, Item ID = B093VLG4BQ, Is Real Item: False
# Rank 445: Score = 79.49, Item ID = B0BYKX32Z8, Is Real Item: False
# Rank 446: Score = 79.49, Item ID = B01JRGNO1O, Is Real Item: False
# Rank 447: Score = 79.48, Item ID = B093LSY57L, Is Real Item: False
# Rank 448: Score = 79.48, Item ID = B00RDG3IAI, Is Real Item: False
# Rank 449: Score = 79.47, Item ID = B075D6LHTT, Is Real Item: False
# Rank 450: Score = 79.47, Item ID = B078GK73TK, Is Real Item: False
# Rank 451: Score = 79.47, Item ID = B07JQ2ZHTL, Is Real Item: False
# Rank 452: Score = 79.47, Item ID = B0BFL82QWC, Is Real Item: False
# Rank 453: Score = 79.46, Item ID = B01M3VQHAR, Is Real Item: False
# Rank 454: Score = 79.46, Item ID = B00MY649QY, Is Real Item: False
# Rank 455: Score = 79.45, Item ID = B001QVOXPU, Is Real Item: False
# Rank 456: Score = 79.45, Item ID = B08QTSSGTB, Is Real Item: False
# Rank 457: Score = 79.44, Item ID = B09ZVN18ZD, Is Real Item: False
# Rank 458: Score = 79.44, Item ID = B0BYN42ZTK, Is Real Item: False
# Rank 459: Score = 79.44, Item ID = B09WY3DHD9, Is Real Item: False
# Rank 460: Score = 79.44, Item ID = B01N0UL4RX, Is Real Item: False
# Rank 461: Score = 79.43, Item ID = B09SJ1WM6P, Is Real Item: False
# Rank 462: Score = 79.42, Item ID = B08SG6K56D, Is Real Item: False
# Rank 463: Score = 79.42, Item ID = B0B8CD25WH, Is Real Item: False
# Rank 464: Score = 79.42, Item ID = B0007WTF2K, Is Real Item: False
# Rank 465: Score = 79.42, Item ID = B0B3XGB4CZ, Is Real Item: False
# Rank 466: Score = 79.42, Item ID = B07YMY31SX, Is Real Item: False
# Rank 467: Score = 79.42, Item ID = B0B8HDP2CH, Is Real Item: False
# Rank 468: Score = 79.41, Item ID = B0BHBDM3RL, Is Real Item: False
# Rank 469: Score = 79.41, Item ID = B09HPYMLTS, Is Real Item: False
# Rank 470: Score = 79.41, Item ID = B07WW99NL9, Is Real Item: False
# Rank 471: Score = 79.41, Item ID = B09Y21PC51, Is Real Item: False
# Rank 472: Score = 79.41, Item ID = B00EFBEGLY, Is Real Item: False
# Rank 473: Score = 79.40, Item ID = B089VWJ7VY, Is Real Item: False
# Rank 474: Score = 79.40, Item ID = B0BXHBCCS6, Is Real Item: False
# Rank 475: Score = 79.40, Item ID = B008N3JT8A, Is Real Item: False
# Rank 476: Score = 79.40, Item ID = B06VVBSFTF, Is Real Item: False
# Rank 477: Score = 79.40, Item ID = B07QSCVQ3R, Is Real Item: False
# Rank 478: Score = 79.39, Item ID = B000CNIMSC, Is Real Item: False
# Rank 479: Score = 79.39, Item ID = B07X6GHLLT, Is Real Item: False
# Rank 480: Score = 79.39, Item ID = B07KHSY99T, Is Real Item: False
# Rank 481: Score = 79.39, Item ID = B09TB24JYP, Is Real Item: False
# Rank 482: Score = 79.38, Item ID = B09CT9NWNT, Is Real Item: False
# Rank 483: Score = 79.38, Item ID = B0BHPZG8CZ, Is Real Item: False
# Rank 484: Score = 79.37, Item ID = B0B7J8Y581, Is Real Item: False
# Rank 485: Score = 79.37, Item ID = B08VW815SQ, Is Real Item: False
# Rank 486: Score = 79.37, Item ID = B0CDSG6X4Y, Is Real Item: False
# Rank 487: Score = 79.36, Item ID = B07STLQ4P9, Is Real Item: False
# Rank 488: Score = 79.36, Item ID = B0C5WTV2XH, Is Real Item: False
# Rank 489: Score = 79.36, Item ID = B0C5WTV2XH, Is Real Item: False
# Rank 490: Score = 79.36, Item ID = B094Q69QHZ, Is Real Item: False
# Rank 491: Score = 79.36, Item ID = B09SFRLGN4, Is Real Item: False
# Rank 492: Score = 79.35, Item ID = B0009EUA0M, Is Real Item: False
# Rank 493: Score = 79.35, Item ID = B0C3HYDM95, Is Real Item: False
# Rank 494: Score = 79.34, Item ID = B08KVCTWFD, Is Real Item: False
# Rank 495: Score = 79.34, Item ID = B07Q2MR6FV, Is Real Item: False
# Rank 496: Score = 79.33, Item ID = B07TCLC2R6, Is Real Item: False
# Rank 497: Score = 79.33, Item ID = B08KVSM9YX, Is Real Item: False
# Rank 498: Score = 79.32, Item ID = B09W18S9RJ, Is Real Item: False
# Rank 499: Score = 79.32, Item ID = B08R6CWDJ8, Is Real Item: False
# Rank 500: Score = 79.31, Item ID = B09RTB73CK, Is Real Item: False
# Rank 501: Score = 79.31, Item ID = B0734QN8KR, Is Real Item: False
# Rank 502: Score = 79.31, Item ID = B07XY51K5R, Is Real Item: False
# Rank 503: Score = 79.31, Item ID = B0BY8FK656, Is Real Item: False
# Rank 504: Score = 79.30, Item ID = B000C59M5M, Is Real Item: False
# Rank 505: Score = 79.30, Item ID = B076FFLDR8, Is Real Item: False
# Rank 506: Score = 79.30, Item ID = B0BD26FP2Q, Is Real Item: False
# Rank 507: Score = 79.30, Item ID = B0B3RN1255, Is Real Item: False
# Rank 508: Score = 79.29, Item ID = B08L8PYRSS, Is Real Item: False
# Rank 509: Score = 79.29, Item ID = B0BRC2F9WD, Is Real Item: False
# Rank 510: Score = 79.29, Item ID = B08HPPBPLT, Is Real Item: False
# Rank 511: Score = 79.29, Item ID = B09V7N8MZL, Is Real Item: False
# Rank 512: Score = 79.29, Item ID = B09TGXTQK7, Is Real Item: False
# Rank 513: Score = 79.29, Item ID = B0C4GY5QJP, Is Real Item: False
# Rank 514: Score = 79.28, Item ID = B0BY8T4KM2, Is Real Item: False
# Rank 515: Score = 79.28, Item ID = B082N17MH1, Is Real Item: False
# Rank 516: Score = 79.28, Item ID = B0B5KNGL12, Is Real Item: False
# Rank 517: Score = 79.28, Item ID = B09VT214ZB, Is Real Item: False
# Rank 518: Score = 79.28, Item ID = B07F361XV6, Is Real Item: False
# Rank 519: Score = 79.28, Item ID = B09R54R2DH, Is Real Item: False
# Rank 520: Score = 79.28, Item ID = B09M3JLSVF, Is Real Item: False
# Rank 521: Score = 79.27, Item ID = B0BX6RJ91Q, Is Real Item: False
# Rank 522: Score = 79.27, Item ID = B0882RV2JT, Is Real Item: False
# Rank 523: Score = 79.27, Item ID = B088RNTPB8, Is Real Item: False
# Rank 524: Score = 79.27, Item ID = B0C4FJWFDH, Is Real Item: False
# Rank 525: Score = 79.27, Item ID = B0BRY1S1SV, Is Real Item: False
# Rank 526: Score = 79.27, Item ID = B0BPRM1BW6, Is Real Item: False
# Rank 527: Score = 79.27, Item ID = B0B8NG9WL2, Is Real Item: False
# Rank 528: Score = 79.27, Item ID = B0BD876MQT, Is Real Item: False
# Rank 529: Score = 79.26, Item ID = B073WH9FGP, Is Real Item: False
# Rank 530: Score = 79.26, Item ID = B0819779C2, Is Real Item: False
# Rank 531: Score = 79.26, Item ID = B0984WQYHD, Is Real Item: False
# Rank 532: Score = 79.26, Item ID = B0BPCC4RQ9, Is Real Item: False
# Rank 533: Score = 79.26, Item ID = B0BN9WXQKB, Is Real Item: False
# Rank 534: Score = 79.26, Item ID = B0BP7GD5MX, Is Real Item: False
# Rank 535: Score = 79.26, Item ID = B08LMNMMS4, Is Real Item: False
# Rank 536: Score = 79.25, Item ID = B0CBBM43VF, Is Real Item: False
# Rank 537: Score = 79.25, Item ID = B0BKPTVZKQ, Is Real Item: False
# Rank 538: Score = 79.25, Item ID = B076SC377J, Is Real Item: False
# Rank 539: Score = 79.25, Item ID = B09C8KFWDT, Is Real Item: False
# Rank 540: Score = 79.24, Item ID = B09GM45XKJ, Is Real Item: False
# Rank 541: Score = 79.24, Item ID = B0B7FP7DKG, Is Real Item: False
# Rank 542: Score = 79.24, Item ID = B09LRYBVXJ, Is Real Item: False
# Rank 543: Score = 79.24, Item ID = B09NLR5GNY, Is Real Item: False
# Rank 544: Score = 79.24, Item ID = B09TWW2BC9, Is Real Item: False
# Rank 545: Score = 79.24, Item ID = B0BM446MNC, Is Real Item: False
# Rank 546: Score = 79.23, Item ID = B09XL9MSKV, Is Real Item: False
# Rank 547: Score = 79.23, Item ID = B08ZM4QM35, Is Real Item: False
# Rank 548: Score = 79.23, Item ID = B01F9KLIP6, Is Real Item: False
# Rank 549: Score = 79.23, Item ID = B00ES5Q7GE, Is Real Item: False
# Rank 550: Score = 79.23, Item ID = B07X2D6G6Y, Is Real Item: False
# Rank 551: Score = 79.22, Item ID = B09L7CPH34, Is Real Item: False
# Rank 552: Score = 79.22, Item ID = B0BS3KDGHQ, Is Real Item: False
# Rank 553: Score = 79.22, Item ID = B085CNLP9R, Is Real Item: False
# Rank 554: Score = 79.21, Item ID = B0736C8CMV, Is Real Item: False
# Rank 555: Score = 79.21, Item ID = B09VDRQPTC, Is Real Item: False
# Rank 556: Score = 79.21, Item ID = B0BVZJHWJ3, Is Real Item: False
# Rank 557: Score = 79.20, Item ID = B0B452YDWT, Is Real Item: False
# Rank 558: Score = 79.20, Item ID = B09X1ZB8S1, Is Real Item: False
# Rank 559: Score = 79.20, Item ID = B0BG2VGZG9, Is Real Item: False
# Rank 560: Score = 79.20, Item ID = B00H7LPKKU, Is Real Item: False
# Rank 561: Score = 79.20, Item ID = B0B9R7PMXS, Is Real Item: False
# Rank 562: Score = 79.19, Item ID = B07ZQZD6WX, Is Real Item: False
# Rank 563: Score = 79.19, Item ID = B0C4PXXH6T, Is Real Item: False
# Rank 564: Score = 79.19, Item ID = B0BPMQ26X1, Is Real Item: False
# Rank 565: Score = 79.18, Item ID = B092RWST8P, Is Real Item: False
# Rank 566: Score = 79.18, Item ID = B07589FJZL, Is Real Item: False
# Rank 567: Score = 79.18, Item ID = B09MQMJFRC, Is Real Item: False
# Rank 568: Score = 79.17, Item ID = B0BBQQC4WS, Is Real Item: False
# Rank 569: Score = 79.17, Item ID = B000CMHKRC, Is Real Item: False
# Rank 570: Score = 79.17, Item ID = B084GDTCT6, Is Real Item: False
# Rank 571: Score = 79.16, Item ID = B0C5RD47PM, Is Real Item: False
# Rank 572: Score = 79.15, Item ID = B091D48TQ8, Is Real Item: False
# Rank 573: Score = 79.15, Item ID = B0BBKRCLXX, Is Real Item: False
# Rank 574: Score = 79.15, Item ID = B07RV1PGPG, Is Real Item: False
# Rank 575: Score = 79.15, Item ID = B08Z85P7JG, Is Real Item: False
# Rank 576: Score = 79.15, Item ID = B01M2CITBM, Is Real Item: False
# Rank 577: Score = 79.14, Item ID = B07NXX4PV4, Is Real Item: False
# Rank 578: Score = 79.14, Item ID = B0BR2NL1RT, Is Real Item: False
# Rank 579: Score = 79.13, Item ID = B08LT7RP8Y, Is Real Item: False
# Rank 580: Score = 79.13, Item ID = B0BSJFXT16, Is Real Item: False
# Rank 581: Score = 79.13, Item ID = B09QFND19V, Is Real Item: False
# Rank 582: Score = 79.13, Item ID = B09N9ZN578, Is Real Item: False
# Rank 583: Score = 79.13, Item ID = B099PB3C11, Is Real Item: False
# Rank 584: Score = 79.13, Item ID = B0BVZ9CDG9, Is Real Item: False
# Rank 585: Score = 79.13, Item ID = B0BVZ9CDG9, Is Real Item: False
# Rank 586: Score = 79.12, Item ID = B08Z32TCKH, Is Real Item: False
# Rank 587: Score = 79.11, Item ID = B07VNT3CJ5, Is Real Item: False
# Rank 588: Score = 79.11, Item ID = B0BND4VNHC, Is Real Item: False
# Rank 589: Score = 79.11, Item ID = B0747W6ZF9, Is Real Item: False
# Rank 590: Score = 79.11, Item ID = B07VTMKQZS, Is Real Item: False
# Rank 591: Score = 79.10, Item ID = B09CHHLJ1H, Is Real Item: False
# Rank 592: Score = 79.10, Item ID = B00S75VRL6, Is Real Item: False
# Rank 593: Score = 79.10, Item ID = B0C542NGGP, Is Real Item: False
# Rank 594: Score = 79.10, Item ID = B09CF9KTPQ, Is Real Item: False
# Rank 595: Score = 79.10, Item ID = B083NBFHW2, Is Real Item: False
# Rank 596: Score = 79.09, Item ID = B09BTW379L, Is Real Item: False
# Rank 597: Score = 79.08, Item ID = B099FGQ61S, Is Real Item: False
# Rank 598: Score = 79.08, Item ID = B08BGSTMR5, Is Real Item: False
# Rank 599: Score = 79.07, Item ID = B09XTZ5QT7, Is Real Item: False
# Rank 600: Score = 79.07, Item ID = B081GNK55B, Is Real Item: False
# Rank 601: Score = 79.06, Item ID = B09RGLZNX9, Is Real Item: False
# Rank 602: Score = 79.04, Item ID = B0BXFCGC9Z, Is Real Item: False
# Rank 603: Score = 79.04, Item ID = B07T7KX7TY, Is Real Item: False
# Rank 604: Score = 79.04, Item ID = B07QNLMKJD, Is Real Item: False
# Rank 605: Score = 79.04, Item ID = B09LM1BZHF, Is Real Item: False
# Rank 606: Score = 79.04, Item ID = B07X13VNYD, Is Real Item: False
# Rank 607: Score = 79.03, Item ID = B089R89T26, Is Real Item: False
# Rank 608: Score = 79.02, Item ID = B072317XNY, Is Real Item: False
# Rank 609: Score = 79.02, Item ID = B0B979DSKM, Is Real Item: False
# Rank 610: Score = 79.01, Item ID = B09Y8P446S, Is Real Item: False
# Rank 611: Score = 79.01, Item ID = B09Y8P446S, Is Real Item: False
# Rank 612: Score = 79.00, Item ID = B0B1Q899WQ, Is Real Item: False
# Rank 613: Score = 79.00, Item ID = B0BP2YSFBV, Is Real Item: False
# Rank 614: Score = 78.99, Item ID = B0BHQL218H, Is Real Item: False
# Rank 615: Score = 78.99, Item ID = B0BYKQQY59, Is Real Item: False
# Rank 616: Score = 78.99, Item ID = B0BFPLY15W, Is Real Item: False
# Rank 617: Score = 78.99, Item ID = B0BKTPLC9G, Is Real Item: False
# Rank 618: Score = 78.99, Item ID = B09H6NGWYF, Is Real Item: False
# Rank 619: Score = 78.98, Item ID = B0732VMKHM, Is Real Item: False
# Rank 620: Score = 78.98, Item ID = B0BYHGD4HC, Is Real Item: False
# Rank 621: Score = 78.98, Item ID = B09TTKH8K6, Is Real Item: False
# Rank 622: Score = 78.97, Item ID = B0C7H753N4, Is Real Item: False
# Rank 623: Score = 78.97, Item ID = B09HZVX4GC, Is Real Item: False
# Rank 624: Score = 78.97, Item ID = B08MZFPNY7, Is Real Item: False
# Rank 625: Score = 78.97, Item ID = B07BW283F5, Is Real Item: False
# Rank 626: Score = 78.97, Item ID = B0BKL9M888, Is Real Item: False
# Rank 627: Score = 78.97, Item ID = B0C23Y82BV, Is Real Item: False
# Rank 628: Score = 78.96, Item ID = B00XAIZ4RS, Is Real Item: False
# Rank 629: Score = 78.96, Item ID = B00RP9DRGI, Is Real Item: False
# Rank 630: Score = 78.96, Item ID = B0B7BG7NNJ, Is Real Item: False
# Rank 631: Score = 78.95, Item ID = B083R1S9DD, Is Real Item: False
# Rank 632: Score = 78.95, Item ID = B08427NZS2, Is Real Item: False
# Rank 633: Score = 78.94, Item ID = B0BMGHQWYS, Is Real Item: False
# Rank 634: Score = 78.93, Item ID = B00LOQHLA6, Is Real Item: False
# Rank 635: Score = 78.93, Item ID = B07KXMLTPS, Is Real Item: False
# Rank 636: Score = 78.93, Item ID = B01D609V78, Is Real Item: False
# Rank 637: Score = 78.93, Item ID = B071D7VCX2, Is Real Item: False
# Rank 638: Score = 78.93, Item ID = B00X123R2W, Is Real Item: False
# Rank 639: Score = 78.93, Item ID = B00XV5C03Q, Is Real Item: False
# Rank 640: Score = 78.93, Item ID = B08NXG7FN4, Is Real Item: False
# Rank 641: Score = 78.92, Item ID = B09KRWBZRL, Is Real Item: False
# Rank 642: Score = 78.91, Item ID = B091MH78B2, Is Real Item: False
# Rank 643: Score = 78.91, Item ID = B0BBL7R77T, Is Real Item: False
# Rank 644: Score = 78.91, Item ID = B09PYLNX9Z, Is Real Item: False
# Rank 645: Score = 78.91, Item ID = B09TQ9GYCT, Is Real Item: False
# Rank 646: Score = 78.91, Item ID = B0B1T7LDFP, Is Real Item: False
# Rank 647: Score = 78.90, Item ID = B095WM55JY, Is Real Item: False
# Rank 648: Score = 78.90, Item ID = B0BLGB136P, Is Real Item: False
# Rank 649: Score = 78.90, Item ID = B0BSKLC8LB, Is Real Item: False
# Rank 650: Score = 78.90, Item ID = B0BSKLC8LB, Is Real Item: False
# Rank 651: Score = 78.90, Item ID = B0C739RP4N, Is Real Item: False
# Rank 652: Score = 78.90, Item ID = B00LD1FCFS, Is Real Item: False
# Rank 653: Score = 78.90, Item ID = B0086UBVOU, Is Real Item: False
# Rank 654: Score = 78.89, Item ID = B081FK4LZY, Is Real Item: False
# Rank 655: Score = 78.89, Item ID = B01LLWKXV6, Is Real Item: False
# Rank 656: Score = 78.89, Item ID = B0B4FS61KC, Is Real Item: False
# Rank 657: Score = 78.88, Item ID = B09P8S38KR, Is Real Item: False
# Rank 658: Score = 78.88, Item ID = B08ZLF88BT, Is Real Item: False
# Rank 659: Score = 78.88, Item ID = B09YH64N6L, Is Real Item: False
# Rank 660: Score = 78.88, Item ID = B07NJJ3DWK, Is Real Item: False
# Rank 661: Score = 78.88, Item ID = B01G0Q61YQ, Is Real Item: False
# Rank 662: Score = 78.88, Item ID = B0BGQP9BL7, Is Real Item: False
# Rank 663: Score = 78.87, Item ID = B00R6DGSAK, Is Real Item: False
# Rank 664: Score = 78.87, Item ID = B016YBDULO, Is Real Item: False
# Rank 665: Score = 78.87, Item ID = B09CDD8PZP, Is Real Item: False
# Rank 666: Score = 78.87, Item ID = B07HX9LD3H, Is Real Item: False
# Rank 667: Score = 78.86, Item ID = B0BRNW3536, Is Real Item: False
# Rank 668: Score = 78.86, Item ID = B0C6LKVC9N, Is Real Item: False
# Rank 669: Score = 78.86, Item ID = B07Y3YY9YX, Is Real Item: False
# Rank 670: Score = 78.86, Item ID = B0BFGCF41N, Is Real Item: False
# Rank 671: Score = 78.85, Item ID = B08PHJH88B, Is Real Item: False
# Rank 672: Score = 78.85, Item ID = B098NJN9K1, Is Real Item: False
# Rank 673: Score = 78.85, Item ID = B085R98GSF, Is Real Item: False
# Rank 674: Score = 78.85, Item ID = B091KN4HR1, Is Real Item: False
# Rank 675: Score = 78.85, Item ID = B0BLSLSBF6, Is Real Item: False
# Rank 676: Score = 78.85, Item ID = B089LX8NLQ, Is Real Item: False
# Rank 677: Score = 78.85, Item ID = B09TFFPHWW, Is Real Item: False
# Rank 678: Score = 78.84, Item ID = B09YV5C58Z, Is Real Item: False
# Rank 679: Score = 78.84, Item ID = B09QPFGYF1, Is Real Item: False
# Rank 680: Score = 78.84, Item ID = B09RPFV8SS, Is Real Item: False
# Rank 681: Score = 78.84, Item ID = B07TYFBGSR, Is Real Item: False
# Rank 682: Score = 78.84, Item ID = B087BLS9RH, Is Real Item: False
# Rank 683: Score = 78.83, Item ID = B088BDWHXV, Is Real Item: False
# Rank 684: Score = 78.83, Item ID = B09GM56893, Is Real Item: False
# Rank 685: Score = 78.83, Item ID = B01HMAG860, Is Real Item: False
# Rank 686: Score = 78.82, Item ID = B07BDFGC9N, Is Real Item: False
# Rank 687: Score = 78.82, Item ID = B071ZPQ7JQ, Is Real Item: False
# Rank 688: Score = 78.82, Item ID = B0CB1WCTWW, Is Real Item: False
# Rank 689: Score = 78.81, Item ID = B01M67ABDG, Is Real Item: False
# Rank 690: Score = 78.80, Item ID = B088BYBFRN, Is Real Item: False
# Rank 691: Score = 78.79, Item ID = B09H5SQPMX, Is Real Item: False
# Rank 692: Score = 78.79, Item ID = B0B4HGGPYH, Is Real Item: False
# Rank 693: Score = 78.79, Item ID = B07J36WCJN, Is Real Item: False
# Rank 694: Score = 78.79, Item ID = B07MWL3YR2, Is Real Item: False
# Rank 695: Score = 78.78, Item ID = B0C49MFT62, Is Real Item: False
# Rank 696: Score = 78.78, Item ID = B0BN42QW1Z, Is Real Item: False
# Rank 697: Score = 78.78, Item ID = B095W7GRW5, Is Real Item: False
# Rank 698: Score = 78.78, Item ID = B095H9P4HD, Is Real Item: False
# Rank 699: Score = 78.78, Item ID = B08BCLMSS3, Is Real Item: False
# Rank 700: Score = 78.78, Item ID = B09LT8PYFX, Is Real Item: False
# Rank 701: Score = 78.78, Item ID = B00HFK76QE, Is Real Item: False
# Rank 702: Score = 78.78, Item ID = B0BDL2X48F, Is Real Item: False
# Rank 703: Score = 78.78, Item ID = B09XJDPYG4, Is Real Item: False
# Rank 704: Score = 78.77, Item ID = B07TWKXNT2, Is Real Item: False
# Rank 705: Score = 78.77, Item ID = B09XBDHLHY, Is Real Item: False
# Rank 706: Score = 78.77, Item ID = B08JC9LWSQ, Is Real Item: False
# Rank 707: Score = 78.77, Item ID = B08JC9LWSQ, Is Real Item: False
# Rank 708: Score = 78.76, Item ID = B08PBV8GL9, Is Real Item: False
# Rank 709: Score = 78.76, Item ID = B09MLHLXDG, Is Real Item: False
# Rank 710: Score = 78.75, Item ID = B0C2J44PLM, Is Real Item: False
# Rank 711: Score = 78.75, Item ID = B0C2J44PLM, Is Real Item: False
# Rank 712: Score = 78.74, Item ID = B093C5LXT8, Is Real Item: False
# Rank 713: Score = 78.74, Item ID = B09D1Q2LFP, Is Real Item: False
# Rank 714: Score = 78.74, Item ID = B0C37W824S, Is Real Item: False
# Rank 715: Score = 78.74, Item ID = B09T1NW3MD, Is Real Item: False
# Rank 716: Score = 78.74, Item ID = B0BYFJXDYF, Is Real Item: False
# Rank 717: Score = 78.74, Item ID = B0BZM8CXVH, Is Real Item: False
# ...
# Rank 763: Score = 78.64, Item ID = B0B618B9GD, Is Real Item: False
# Rank 764: Score = 78.63, Item ID = B09ZQRKG5P, Is Real Item: False
# Rank 765: Score = 78.63, Item ID = B0842CPP1G, Is Real Item: False
# Rank 766: Score = 78.63, Item ID = B00NF1QQ18, Is Real Item: False
# Rank 767: Score = 78.63, Item ID = B08515C4TK, Is Real Item: False
# Rank 768: Score = 78.63, Item ID = B09VK58NS4, Is Real Item: False
# Rank 769: Score = 78.62, Item ID = B083Z4XTRG, Is Real Item: False
# Rank 770: Score = 78.62, Item ID = B0C3J5FSJP, Is Real Item: False
# Rank 771: Score = 78.62, Item ID = B09CJD5V8Q, Is Real Item: False
# Rank 772: Score = 78.61, Item ID = B0BDFWDMRK, Is Real Item: False
# Rank 773: Score = 78.61, Item ID = B0B93X4B7C, Is Real Item: False
# Rank 774: Score = 78.60, Item ID = B07WS6HRY1, Is Real Item: False
# Rank 775: Score = 78.60, Item ID = B08TM7796B, Is Real Item: False
# Rank 776: Score = 78.60, Item ID = B0BXRSH23P, Is Real Item: False
# Rank 777: Score = 78.60, Item ID = B06X6KM4RS, Is Real Item: False
# Rank 778: Score = 78.60, Item ID = B08D9FWVJD, Is Real Item: False
# Rank 779: Score = 78.60, Item ID = B08D9FWVJD, Is Real Item: False
# Rank 780: Score = 78.60, Item ID = B08D9FWVJD, Is Real Item: False
# Rank 781: Score = 78.60, Item ID = B08D9FWVJD, Is Real Item: False
# Rank 782: Score = 78.60, Item ID = B09F6H187M, Is Real Item: False
# Rank 783: Score = 78.60, Item ID = B084YQH1BH, Is Real Item: False
# Rank 784: Score = 78.60, Item ID = B07SHB6QLB, Is Real Item: False
# Rank 785: Score = 78.59, Item ID = B008PAIWCA, Is Real Item: False
# Rank 786: Score = 78.59, Item ID = B0C5QD6YZH, Is Real Item: False
# Rank 787: Score = 78.58, Item ID = B0BBV8GR9Q, Is Real Item: False
# Rank 788: Score = 78.58, Item ID = B0B4HW4HZS, Is Real Item: False
# Rank 789: Score = 78.58, Item ID = B0BK8S5NMV, Is Real Item: False
# Rank 790: Score = 78.57, Item ID = B07NK3J9BF, Is Real Item: False
# Rank 791: Score = 78.57, Item ID = B09TYZMWMN, Is Real Item: False
# Rank 792: Score = 78.57, Item ID = B003C1Q98G, Is Real Item: False
# Rank 793: Score = 78.57, Item ID = B0B619FNM3, Is Real Item: False
# Rank 794: Score = 78.57, Item ID = B07F3MG5D5, Is Real Item: False
# Rank 795: Score = 78.57, Item ID = B082V4NTV3, Is Real Item: False
# Rank 796: Score = 78.57, Item ID = B08B9FTYDG, Is Real Item: False
# Rank 797: Score = 78.57, Item ID = B08BYTLSYQ, Is Real Item: False
# Rank 798: Score = 78.56, Item ID = B0B6FX14KN, Is Real Item: False
# Rank 799: Score = 78.56, Item ID = B09LTX5KGW, Is Real Item: False
# Rank 800: Score = 78.56, Item ID = B081FGJ6YN, Is Real Item: False
# Rank 801: Score = 78.56, Item ID = B0BZY1LQW8, Is Real Item: False
# Rank 802: Score = 78.56, Item ID = B083K1PV27, Is Real Item: False
# Rank 803: Score = 78.56, Item ID = B07LGKM9VP, Is Real Item: False
# Rank 804: Score = 78.55, Item ID = B000OAEN7C, Is Real Item: False
# Rank 805: Score = 78.55, Item ID = B082ZQ2Y1W, Is Real Item: False
# Rank 806: Score = 78.54, Item ID = B0B5WHFZCT, Is Real Item: False
# Rank 807: Score = 78.54, Item ID = B0B5WHFZCT, Is Real Item: False
# Rank 808: Score = 78.54, Item ID = B0BGM46555, Is Real Item: False
# Rank 809: Score = 78.54, Item ID = B07QBFTP8C, Is Real Item: False
# Rank 810: Score = 78.53, Item ID = B085L9YD9N, Is Real Item: False
# Rank 811: Score = 78.53, Item ID = B087GT798V, Is Real Item: False
# Rank 812: Score = 78.52, Item ID = B07WFJHPFY, Is Real Item: False
# Rank 813: Score = 78.52, Item ID = B07TKDJ5Q7, Is Real Item: False
# Rank 814: Score = 78.51, Item ID = B007WPCGQW, Is Real Item: False
# Rank 815: Score = 78.50, Item ID = B07PS1H79S, Is Real Item: False
# Rank 816: Score = 78.50, Item ID = B0C2CMJ7KM, Is Real Item: False
# Rank 817: Score = 78.50, Item ID = B00U2UTXTM, Is Real Item: False
# Rank 818: Score = 78.50, Item ID = B08DNQFTWL, Is Real Item: False
# Rank 819: Score = 78.50, Item ID = B075F214K1, Is Real Item: False
# Rank 820: Score = 78.50, Item ID = B0BC24P6WZ, Is Real Item: False
# Rank 821: Score = 78.50, Item ID = B08YCS22DR, Is Real Item: False
# Rank 822: Score = 78.49, Item ID = B071SFPSPS, Is Real Item: False
# Rank 823: Score = 78.49, Item ID = B095PP7GDC, Is Real Item: False
# Rank 824: Score = 78.49, Item ID = B00NZDE9GU, Is Real Item: False
# Rank 825: Score = 78.49, Item ID = B0C3VKMDTN, Is Real Item: False
# Rank 826: Score = 78.48, Item ID = B09MJ2PH1D, Is Real Item: False
# Rank 827: Score = 78.48, Item ID = B0BHYXW262, Is Real Item: False
# Rank 828: Score = 78.47, Item ID = B004J3AZZO, Is Real Item: False
# Rank 829: Score = 78.46, Item ID = B08D7FN6M5, Is Real Item: False
# Rank 830: Score = 78.46, Item ID = B089VCX77J, Is Real Item: False
# Rank 831: Score = 78.46, Item ID = B0BV6FLFGN, Is Real Item: False
# Rank 832: Score = 78.45, Item ID = B0C3QPNZ2L, Is Real Item: False
# Rank 833: Score = 78.45, Item ID = B0BS13VWCJ, Is Real Item: False
# Rank 834: Score = 78.45, Item ID = B07XLGCQ4J, Is Real Item: False
# Rank 835: Score = 78.44, Item ID = B0BBPS3PX4, Is Real Item: False
# Rank 836: Score = 78.44, Item ID = B0C2WP51BP, Is Real Item: False
# Rank 837: Score = 78.44, Item ID = B09F8SMW6Q, Is Real Item: False
# Rank 838: Score = 78.44, Item ID = B00KJLMGYI, Is Real Item: False
# Rank 839: Score = 78.44, Item ID = B078RLQ7WG, Is Real Item: False
# Rank 840: Score = 78.44, Item ID = B0C86NVY4N, Is Real Item: False
# Rank 841: Score = 78.43, Item ID = B09N6MF3P9, Is Real Item: False
# Rank 842: Score = 78.43, Item ID = B0C64JQPXJ, Is Real Item: False
# Rank 843: Score = 78.43, Item ID = B07RXQW6F8, Is Real Item: False
# Rank 844: Score = 78.43, Item ID = B0858RXWHJ, Is Real Item: False
# Rank 845: Score = 78.42, Item ID = B01N4KCFN1, Is Real Item: False
# Rank 846: Score = 78.42, Item ID = B07PJRXQ3J, Is Real Item: False
# Rank 847: Score = 78.42, Item ID = B082LPR5Q9, Is Real Item: False
# Rank 848: Score = 78.42, Item ID = B084F9F2BL, Is Real Item: False
# Rank 849: Score = 78.42, Item ID = B084F9F2BL, Is Real Item: False
# Rank 850: Score = 78.42, Item ID = B084F9F2BL, Is Real Item: False
# Rank 851: Score = 78.42, Item ID = B095HN6M3J, Is Real Item: False
# Rank 852: Score = 78.41, Item ID = B09GDC2H3D, Is Real Item: False
# Rank 853: Score = 78.41, Item ID = B074BDB8W2, Is Real Item: False
# Rank 854: Score = 78.41, Item ID = B0B3F9BFCM, Is Real Item: False
# Rank 855: Score = 78.41, Item ID = B0BYD3CR4K, Is Real Item: False
# Rank 856: Score = 78.41, Item ID = B0BYF9JNJF, Is Real Item: False
# Rank 857: Score = 78.41, Item ID = B0B8T8L8TY, Is Real Item: False
# Rank 858: Score = 78.40, Item ID = B0BPBCYKKT, Is Real Item: False
# Rank 859: Score = 78.40, Item ID = B09422G6DG, Is Real Item: False
# Rank 860: Score = 78.40, Item ID = B0B5Y43QM3, Is Real Item: False
# Rank 861: Score = 78.40, Item ID = B09CPN5CVF, Is Real Item: False
# Rank 862: Score = 78.40, Item ID = B0BV2GHKFX, Is Real Item: False
# Rank 863: Score = 78.39, Item ID = B0BL6RCG39, Is Real Item: False
# Rank 864: Score = 78.39, Item ID = B09R1JP1HG, Is Real Item: False
# Rank 865: Score = 78.39, Item ID = B0C7JLCS1J, Is Real Item: False
# Rank 866: Score = 78.39, Item ID = B07DCDHTD6, Is Real Item: False
# Rank 867: Score = 78.39, Item ID = B07BTPX325, Is Real Item: False
# Rank 868: Score = 78.38, Item ID = B07PT8L51K, Is Real Item: False
# Rank 869: Score = 78.38, Item ID = B0CBMYHZYV, Is Real Item: False
# Rank 870: Score = 78.37, Item ID = B09ZQN7PNH, Is Real Item: False
# Rank 871: Score = 78.37, Item ID = B09TN26JN9, Is Real Item: False
# Rank 872: Score = 78.36, Item ID = B0C4V5PGXN, Is Real Item: False
# Rank 873: Score = 78.36, Item ID = B09MJZDTVM, Is Real Item: False
# Rank 874: Score = 78.36, Item ID = B09QFSYHLQ, Is Real Item: False
# Rank 875: Score = 78.36, Item ID = B08JSMRM3J, Is Real Item: False
# Rank 876: Score = 78.36, Item ID = B014UX1GUU, Is Real Item: False
# Rank 877: Score = 78.35, Item ID = B07H899LT7, Is Real Item: False
# Rank 878: Score = 78.35, Item ID = B07SX5M9R6, Is Real Item: False
# Rank 879: Score = 78.34, Item ID = B0BDDFHGNK, Is Real Item: False
# Rank 880: Score = 78.34, Item ID = B08L1N1VYN, Is Real Item: False
# Rank 881: Score = 78.33, Item ID = B098NB228X, Is Real Item: False
# Rank 882: Score = 78.33, Item ID = B07Y45J8BV, Is Real Item: False
# Rank 883: Score = 78.33, Item ID = B07DGTT2NZ, Is Real Item: False
# Rank 884: Score = 78.32, Item ID = B0CBDH57WG, Is Real Item: False
# Rank 885: Score = 78.32, Item ID = B091YFGFSY, Is Real Item: False
# Rank 886: Score = 78.32, Item ID = B07GXB6GM7, Is Real Item: False
# Rank 887: Score = 78.32, Item ID = B096RPC8X2, Is Real Item: False
# Rank 888: Score = 78.32, Item ID = B004MDXS0U, Is Real Item: False
# Rank 889: Score = 78.31, Item ID = B0C42KHK35, Is Real Item: False
# Rank 890: Score = 78.30, Item ID = B0B1HWJK9M, Is Real Item: False
# Rank 891: Score = 78.30, Item ID = B0B8QWH7VT, Is Real Item: False
# Rank 892: Score = 78.30, Item ID = B0019GOLVS, Is Real Item: False
# Rank 893: Score = 78.30, Item ID = B087PTNHMF, Is Real Item: False
# Rank 894: Score = 78.29, Item ID = B0BK874VSS, Is Real Item: False
# Rank 895: Score = 78.29, Item ID = B0B9PWK777, Is Real Item: False
# Rank 896: Score = 78.29, Item ID = B0B2S765X8, Is Real Item: False
# Rank 897: Score = 78.28, Item ID = B0C5WFZZL8, Is Real Item: False
# Rank 898: Score = 78.28, Item ID = B017JD2ZBM, Is Real Item: False
# Rank 899: Score = 78.28, Item ID = B081J3Q91B, Is Real Item: False
# Rank 900: Score = 78.28, Item ID = B09WCXCKY2, Is Real Item: False
# Rank 901: Score = 78.28, Item ID = B0BZLKXL9Z, Is Real Item: False
# Rank 902: Score = 78.27, Item ID = B07GTBVC4Z, Is Real Item: False
# Rank 903: Score = 78.27, Item ID = B08VDJ7C7F, Is Real Item: False
# Rank 904: Score = 78.27, Item ID = B0B8H9XQWD, Is Real Item: False
# Rank 905: Score = 78.27, Item ID = B0BR7S7P5R, Is Real Item: False
# Rank 906: Score = 78.27, Item ID = B07P3Z8BVG, Is Real Item: False
# Rank 907: Score = 78.27, Item ID = B006494RXC, Is Real Item: False
# Rank 908: Score = 78.27, Item ID = B0759BB9LV, Is Real Item: False
# Rank 909: Score = 78.27, Item ID = B07T3267K5, Is Real Item: False
# Rank 910: Score = 78.26, Item ID = B09V71SQRJ, Is Real Item: False
# Rank 911: Score = 78.26, Item ID = B0CD7W9FLX, Is Real Item: False
# Rank 912: Score = 78.26, Item ID = B081QW449Q, Is Real Item: False
# Rank 913: Score = 78.26, Item ID = B0777H71MD, Is Real Item: False
# Rank 914: Score = 78.26, Item ID = B0C59HR89D, Is Real Item: False
# Rank 915: Score = 78.26, Item ID = B07W21RVKD, Is Real Item: False
# Rank 916: Score = 78.26, Item ID = B08P53H3S9, Is Real Item: False
# Rank 917: Score = 78.26, Item ID = B097P664V2, Is Real Item: False
# Rank 918: Score = 78.25, Item ID = B077V2FMM9, Is Real Item: False
# Rank 919: Score = 78.25, Item ID = B01BPENQHI, Is Real Item: False
# Rank 920: Score = 78.25, Item ID = B08468XXMD, Is Real Item: False
# Rank 921: Score = 78.25, Item ID = B086XC97FL, Is Real Item: False
# Rank 922: Score = 78.24, Item ID = B09WFLP8Q6, Is Real Item: False
# Rank 923: Score = 78.24, Item ID = B0BY8ZDV11, Is Real Item: False
# Rank 924: Score = 78.24, Item ID = B0BZJYJ2YK, Is Real Item: False
# Rank 925: Score = 78.24, Item ID = B08W5CVK5Z, Is Real Item: False
# Rank 926: Score = 78.24, Item ID = B08WRFFJ9H, Is Real Item: False
# Rank 927: Score = 78.24, Item ID = B002T3FTTI, Is Real Item: False
# Rank 928: Score = 78.23, Item ID = B0BZJBBB13, Is Real Item: False
# Rank 929: Score = 78.23, Item ID = B09L8H35CZ, Is Real Item: False
# Rank 930: Score = 78.23, Item ID = B0C2DLZ128, Is Real Item: False
# Rank 931: Score = 78.23, Item ID = B0C2DLZ128, Is Real Item: False
# Rank 932: Score = 78.23, Item ID = B079WMBD5K, Is Real Item: False
# Rank 933: Score = 78.22, Item ID = B06XCR8RF3, Is Real Item: False
# Rank 934: Score = 78.22, Item ID = B0BLXND3SF, Is Real Item: False
# Rank 935: Score = 78.22, Item ID = B0000CBILL, Is Real Item: False
# Rank 936: Score = 78.21, Item ID = B0921Q4J78, Is Real Item: False
# Rank 937: Score = 78.20, Item ID = B08HK4FY28, Is Real Item: False
# Rank 938: Score = 78.19, Item ID = B08NFGMLFD, Is Real Item: False
# Rank 939: Score = 78.19, Item ID = B0C5LL1LNW, Is Real Item: False
# Rank 940: Score = 78.19, Item ID = B0BGFR76CF, Is Real Item: False
# Rank 941: Score = 78.18, Item ID = B09G6XDY8C, Is Real Item: False
# Rank 942: Score = 78.18, Item ID = B07SDM6VS3, Is Real Item: False
# Rank 943: Score = 78.18, Item ID = B00Y1HRMFO, Is Real Item: False
# Rank 944: Score = 78.17, Item ID = B09NGV1ZW2, Is Real Item: False
# Rank 945: Score = 78.17, Item ID = B07BQRWTDJ, Is Real Item: False
# Rank 946: Score = 78.17, Item ID = B0C4ZTG3KQ, Is Real Item: False
# Rank 947: Score = 78.17, Item ID = B0C4ZTG3KQ, Is Real Item: False
# Rank 948: Score = 78.16, Item ID = B09LHYMKCY, Is Real Item: False
# Rank 949: Score = 78.16, Item ID = B0B2MLNP65, Is Real Item: False
# Rank 950: Score = 78.16, Item ID = B00GG8WSL4, Is Real Item: False
# Rank 951: Score = 78.16, Item ID = B09YRQQ6FC, Is Real Item: False
# Rank 952: Score = 78.16, Item ID = B0CF5CTZ1T, Is Real Item: False
# Rank 953: Score = 78.15, Item ID = B09FYY5K68, Is Real Item: False
# Rank 954: Score = 78.15, Item ID = B0BV2YZ7FV, Is Real Item: False
# Rank 955: Score = 78.15, Item ID = B073ZJC763, Is Real Item: False
# Rank 956: Score = 78.14, Item ID = B07D2RRX4V, Is Real Item: False
# Rank 957: Score = 78.14, Item ID = B07Q5FWQ9P, Is Real Item: False
# Rank 958: Score = 78.14, Item ID = B09S2BTDKD, Is Real Item: False
# Rank 959: Score = 78.13, Item ID = B08S7S9VH4, Is Real Item: False
# Rank 960: Score = 78.13, Item ID = B0BR3WX43Z, Is Real Item: False
# Rank 961: Score = 78.13, Item ID = B09MJRM3F7, Is Real Item: False
# Rank 962: Score = 78.13, Item ID = B09MJRM3F7, Is Real Item: False
# Rank 963: Score = 78.12, Item ID = B07HJXF54B, Is Real Item: False
# Rank 964: Score = 78.12, Item ID = B08R6DR6LV, Is Real Item: False
# Rank 965: Score = 78.12, Item ID = B0B7RN2KD4, Is Real Item: False
# Rank 966: Score = 78.12, Item ID = B091CBQHYV, Is Real Item: False
# Rank 967: Score = 78.12, Item ID = B0B3YYRXMC, Is Real Item: False
# Rank 968: Score = 78.12, Item ID = B083J5NTMP, Is Real Item: False
# Rank 969: Score = 78.11, Item ID = B07WLRJNTJ, Is Real Item: False
# Rank 970: Score = 78.11, Item ID = B09PHB3KFN, Is Real Item: False
# Rank 971: Score = 78.11, Item ID = B09GTV79HK, Is Real Item: False
# Rank 972: Score = 78.11, Item ID = B0BFVWD3ZD, Is Real Item: False
# Rank 973: Score = 78.10, Item ID = B0C34431G8, Is Real Item: False
# Rank 974: Score = 78.10, Item ID = B091N5RTLW, Is Real Item: False
# Rank 975: Score = 78.10, Item ID = B0B8VM839Q, Is Real Item: False
# Rank 976: Score = 78.10, Item ID = B096V3ZM8Q, Is Real Item: False
# Rank 977: Score = 78.10, Item ID = B0B6BHTJ12, Is Real Item: False
# Rank 978: Score = 78.09, Item ID = B09HXLBV3M, Is Real Item: False
# Rank 979: Score = 78.08, Item ID = B093TVBQC3, Is Real Item: False
# Rank 980: Score = 78.08, Item ID = B07F92BX3P, Is Real Item: False
# Rank 981: Score = 78.08, Item ID = B074PTBP82, Is Real Item: False
# Rank 982: Score = 78.07, Item ID = B0C9GK4QNV, Is Real Item: False
# Rank 983: Score = 78.07, Item ID = B095S7L5FD, Is Real Item: False
# Rank 984: Score = 78.07, Item ID = B01MQYDOFA, Is Real Item: False
# Rank 985: Score = 78.07, Item ID = B0BPJKBR36, Is Real Item: False
# Rank 986: Score = 78.07, Item ID = B09Y39Y62X, Is Real Item: False
# Rank 987: Score = 78.07, Item ID = B0BCTSXFSC, Is Real Item: False
# Rank 988: Score = 78.07, Item ID = B0C2TXTKKX, Is Real Item: False
# Rank 989: Score = 78.06, Item ID = B009L1MXE0, Is Real Item: False
# Rank 990: Score = 78.06, Item ID = B09CPYDXRC, Is Real Item: False
# Rank 991: Score = 78.05, Item ID = B01LQ2217A, Is Real Item: False
# Rank 992: Score = 78.04, Item ID = B08TWJ6KMN, Is Real Item: False
# Rank 993: Score = 78.04, Item ID = B0BY56Z8S5, Is Real Item: False
# Rank 994: Score = 78.04, Item ID = B0CC217WKB, Is Real Item: False
# Rank 995: Score = 78.04, Item ID = B09LC88XRS, Is Real Item: False
# Rank 996: Score = 78.03, Item ID = B07LGW21LM, Is Real Item: False
# Rank 997: Score = 78.03, Item ID = B07LGW21LM, Is Real Item: False
# Rank 998: Score = 78.03, Item ID = B0737D1SHS, Is Real Item: False
# Rank 999: Score = 78.03, Item ID = B08KG7D13D, Is Real Item: False
# Rank 1000: Score = 78.02, Item ID = B08BFDLPNZ, Is Real Item: False

# %%
print(len(result_list[2]['matched_items']))
# Out:
# 3468

# %%
import torch
import torch.nn.functional as F
from tqdm import tqdm  # 引入 tqdm

real_item_in_top200_count = 0  # 记录 top-10 中包含 real_item 的次数
total_results = min(100, len(result_list))  # 只处理前 100 个结果

for result in tqdm(result_list[:100], desc="Processing Results", unit="result"):
    query = []
    passages = []
    query.append(f"query: {result['query']}")

    for matched_item in result['matched_items']:
        passages.append(f"passage: {matched_item['metadata']}")

    # Combine query and passages into input_texts
    input_texts = query + passages

    # Tokenize inputs
    batch_dict = tokenizer(
        input_texts,
        max_length=128,
        padding=True,
        truncation=True,
        return_tensors='pt'
    )
    batch_dict = {key: value.to(device) for key, value in batch_dict.items()}

    # Get embeddings
    with torch.no_grad():
        outputs = model(**batch_dict)
        embeddings = average_pool(outputs.last_hidden_state, batch_dict['attention_mask'])
    embeddings = F.normalize(embeddings, p=2, dim=1)

    # Compute scores
    scores = (embeddings[:1] @ embeddings[1:].T) * 100  # Compute similarity scores
    scores = scores.squeeze(0)  # Remove extra dimension for easier processing

    # Get top-10 scores and corresponding indices
    top_scores, top_indices = torch.topk(scores, k=200)

    # Map top scores to matched_items and check if real_item is in top-10
    top_matched_items = [result['matched_items'][idx] for idx in top_indices]

    # Check if real_item is in top-10
    real_item_found = any(matched_item['item_id'] == result['real_item_id'] for matched_item in top_matched_items)

    # Update count if real_item is found in top-10
    if real_item_found:
        real_item_in_top200_count += 1

# Calculate the probability
if total_results > 0:
    probability = real_item_in_top200_count / total_results
else:
    probability = 0.0

print(f"\nProbability of real_item appearing in top-200: {probability:.2%}")
# Out:
# Processing Results: 100%|██████████| 100/100 [02:43<00:00,  1.63s/result]
# Probability of real_item appearing in top-200: 79.00%

# %%
import torch
import torch.nn.functional as F
from tqdm import tqdm  # 引入 tqdm

real_item_in_top200_count = 0  # 记录 top-k 中包含 real_item 的次数
total_results = len(result_list)  # 总结果数

for result in tqdm(result_list, desc="Processing Results", unit="result"):  # 遍历所有结果
    query = []
    passages = []
    query.append(f"query: {result['query']}")

    for matched_item in result['matched_items']:
        passages.append(f"passage: {matched_item['metadata']}")

    # Combine query and passages into input_texts
    input_texts = query + passages

    # Tokenize inputs
    batch_dict = tokenizer(
        input_texts,
        max_length=128,
        padding=True,
        truncation=True,
        return_tensors='pt'
    )
    batch_dict = {key: value.to(device) for key, value in batch_dict.items()}

    # Get embeddings
    with torch.no_grad():
        outputs = model(**batch_dict)
        embeddings = average_pool(outputs.last_hidden_state, batch_dict['attention_mask'])
    embeddings = F.normalize(embeddings, p=2, dim=1)

    # Compute scores
    scores = (embeddings[:1] @ embeddings[1:].T) * 100  # Compute similarity scores
    scores = scores.squeeze(0)  # Remove extra dimension for easier processing

    # Dynamically determine top-k value
    k = min(200, scores.size(0))  # Ensure k does not exceed the number of scores

    # Get top-k scores and corresponding indices
    top_scores, top_indices = torch.topk(scores, k=k)

    # Map top scores to matched_items and check if real_item is in top-k
    top_matched_items = [result['matched_items'][idx] for idx in top_indices]

    # Check if real_item is in top-k
    real_item_found = any(matched_item['item_id'] == result['real_item_id'] for matched_item in top_matched_items)

    # Update count if real_item is found in top-k
    if real_item_found:
        real_item_in_top200_count += 1

# Calculate the probability
if total_results > 0:
    probability = real_item_in_top200_count / total_results
else:
    probability = 0.0

print(f"\nProbability of real_item appearing in top-200: {probability:.2%}")
# Out:
# Processing Results: 100%|██████████| 2025/2025 [53:34<00:00,  1.59s/result]
# Probability of real_item appearing in top-200: 74.07%
